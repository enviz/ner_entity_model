# %% [markdown]
# Candidate details:
#
# Name: Natraj Vikram
#
# email: vikram.iisccamp@gmail.com

# %% [markdown]
# ### Problem Statement
#
# Given: An XLS with the following columns:-
#
# - line_item_name: this is the raw line item name extracted from the invoice
# - line_item_description: this is the raw line item description extracted from the invoice
# - canonical_vendor_name: this is the canonical vendor name to which the invoice has been mapped
# - canonical_line_item_name: this is the canonical line item name to which the raw line item name has been mapped / will be mapped
#
#
# ### Task and objective:
# - Map raw line item names (with descriptions) on invoices to canonical line itemnames.
#
# This is a common task in NLP known as entity linking.

# %% [markdown]
# ### Approach used:
#
# - The dataset given is labeled.
#
# - Since the amount of data given to us is very limited , we can't expect good performance if we train a model from scratch. The resulting output may not be good because the corpus size provided is not enough for the model to train and generalize well.
#
# - Therefore, we train a custom NER model by fine tuning some existing pretrained language models from spaCy.
#
# - For this,I've fine tune 3 language models from spacy namely :- en_core_web_sm,en_core_web_md and en_core_web_lg.

# %% [markdown]
# ### Adding custom labels to the existing spacy nlp model:
#
# - The spaCy library offers pretrained entity extractors.(Person,Organization,Country etc.)
#
# - But for custom business case use requirements,in financial and marketing domains,these pre-existing entities may not be enough. Therefore,we add a new entity called "CLI",short for canonical line item and provide that in the training data.
# - After training,We will try to find out what parts of text belong to the entity type CLI using the test/eval data.

# %%
#Import all the necessary libraries
import pandas as pd
from tqdm import tqdm,trange
import numpy as np
import re
import spacy
import random

# %%
# Load pre-existing spacy language model with english corpus

# nlp=spacy.load('en_core_web_sm')
# nlp=spacy.load('en_core_web_md')
nlp=spacy.load('en_core_web_lg')

# %%
nlp.pipe_names
#predefined pipe names already present in the model
# Out:
# ['tagger', 'parser', 'ner']

# %%
# Getting the pipeline component
ner=nlp.get_pipe("ner")

# %%
df = pd.read_excel('Task.xlsx',sheet_name='train')
df = df.fillna('')
df['line_item_name'] = df['line_item_name'].astype(str) 
df['line_item_description'] = df['line_item_description'].astype(str)

# %%
#Since we have to map raw line item names (with descriptions) on invoices to canonical line itemnames,
#we create a new column name_desc which will combine item name with description
df['name_desc'] = np.zeros(len(df))
for i in trange(len(df)):
    df['name_desc'].iloc[i] = df['line_item_name'].iloc[i] + ' ' + df['line_item_description'].iloc[i]
# Out:
#   0%|          | 0/659 [00:00<?, ?it/s]/home/vikram/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 100%|██████████| 659/659 [00:00<00:00, 8497.93it/s]

# %% [markdown]
# ### Prepare train data
# - As per the spaCy documentation,the train data should be present in the following format.
# - The format of the training data is a list of tuples. Each tuple contains the example text and a dictionary. The dictionary will have the key entities , that stores the start and end indices along with the label of the entitties present in the text.
#
# - For example , To pass “Pizza is a common fast food” as example the format will be :
# ("Pizza is a common fast food",{"entities" : [(0, 5, "FOOD")]})

# %%
def find_start_end(string,substring):
    start = string.index(substring)
    end = string.index(substring) + len(substring) 
    return start,end  ## this returns start and end indices of a substring

# %%
ix = []
ent = []
ent_ix = []
for i in trange(len(df)):
    try:
        
        ent.append([find_start_end(df['name_desc'].iloc[i],df['canonical_line_item_name'].iloc[i])+("CLI",)])
        ent_ix.append(i)
        
    except:
        ent.append(0)
        ix.append(i)
# Out:
# 100%|██████████| 659/659 [00:00<00:00, 59172.08it/s]

# %%
df['entities'] = ent

# %%
df = df[df.entities != 0]

# %%
df = df[['line_item_name', 'line_item_description', 'canonical_vendor_name',
       'name_desc', 'canonical_line_item_name','entities']]

# %%
df
# Out:
#                                         line_item_name  \
# 0                                  Management Services
# 1                                   June Web Media Fee
# 2                                   June Web Media Fee
# 3                                     Business Package
# 4                                         SEO Services
# ..                                                 ...
# 545       Domain Privacy Registration Fees via $261.70
# 547  Business Hosting (Year, USD) (at $432.00 / yea...
# 598                          Service address charge x4
# 604                Workable Annual Plan - Platform fee
# 605  WPBakery Page Builder (Regular License) One ye...
#
#            line_item_description     canonical_vendor_name  \
# 0            April 2019 Services        10 Minute Ventures
# 1    ($249,300 x 12% Commission)  Acqcom Digital Marketing
# 2    ($180,000 x 12% Commission)  Acqcom Digital Marketing
# 3                                                   Adjust
# 4                                                   AdLift
# ..                           ...                       ...
# 545                                      Waltz Media Group
# 547                                                Webflow
# 598    Service address charge x4            Wilson Stevens
# 604                                               Workable
# 605                                  WPBakery Page Builder
#
#                                              name_desc  \
# 0              Management Services April 2019 Services
# 1       June Web Media Fee ($249,300 x 12% Commission)
# 2       June Web Media Fee ($180,000 x 12% Commission)
# 3                                    Business Package
# 4                                        SEO Services
# ..                                                 ...
# 545      Domain Privacy Registration Fees via $261.70
# 547  Business Hosting (Year, USD) (at $432.00 / yea...
# 598  Service address charge x4 Service address char...
# 604               Workable Annual Plan - Platform fee
# 605  WPBakery Page Builder (Regular License) One ye...
#
#                     canonical_line_item_name        entities
# 0                        Management Services  [(0, 19, CLI)]
# 1                              Web Media Fee  [(5, 18, CLI)]
# 2                              Web Media Fee  [(5, 18, CLI)]
# 3                           Business Package  [(0, 16, CLI)]
# 4                               SEO Services  [(0, 12, CLI)]
# ..                                       ...             ...
# 545         Domain Privacy Registration Fees  [(0, 32, CLI)]
# 547                         Business Hosting  [(0, 16, CLI)]
# 598                   Service address charge  [(0, 22, CLI)]
# 604      Workable Annual Plan - Platform fee  [(0, 35, CLI)]
# 605  WPBakery Page Builder (Regular License)  [(0, 39, CLI)]
#
# [349 rows x 6 columns]

# %%
TRAIN_DATA = []
for i in range(len(df)):
    TRAIN_DATA.append((df['name_desc'].iloc[i],{'entities':df['entities'].iloc[i]}))

# %%
TRAIN_DATA[0:5]
#first 5 points from the train data
# Out:
# [('Management Services April 2019 Services', {'entities': [(0, 19, 'CLI')]}),
#  ('June Web Media Fee ($249,300 x 12% Commission)',
#   {'entities': [(5, 18, 'CLI')]}),
#  ('June Web Media Fee ($180,000 x 12% Commission)',
#   {'entities': [(5, 18, 'CLI')]}),
#  ('Business Package ', {'entities': [(0, 16, 'CLI')]}),
#  ('SEO Services ', {'entities': [(0, 12, 'CLI')]})]

# %%
#Adding labels to the `ner`
# Adding custom label CLI - canonical line item
for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# ner.add_label("CLI")
# assert "CLI" in ner.labels

# %%
ner.labels
#here we see that the CLI has been added. Just a sanity check.
# Out:
# ('CARDINAL',
#  'CLI',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
ner.labels[1]
# Out:
# 'CLI'

# %%
# Disable pipeline components you dont need to change
# pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
pipe_exceptions = ["ner"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
unaffected_pipes
# Out:
# ['tagger', 'parser']

# %% [markdown]
# ### Train model

# %%
# Import requirements
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):
    
    optimizer = nlp.resume_training()

  # Training for 30 iterations
    for iteration in trange(30):
        

    # shuufling examples  before every iteration
        random.shuffle(TRAIN_DATA)
        losses = {}
        # batch up the examples using spaCy's minibatch
        batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(
                        texts,  # batch of texts
                        annotations,  # batch of annotations
                        drop=0.5,  # dropout - make it harder to memorise data
                        losses=losses,
                        sgd = optimizer
                    )
            print("Losses", losses)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Losses {'ner': 66.65388107299805}
# Losses {'ner': 150.91592979431152}
# Losses {'ner': 196.2850785255432}
# Losses {'ner': 253.73339128494263}
# Losses {'ner': 309.7413754463196}
# Losses {'ner': 387.25587224960327}
# Losses {'ner': 453.43138456344604}
# Losses {'ner': 571.7008635997772}
# Losses {'ner': 597.9463069438934}
# Losses {'ner': 617.8466880321503}
# Losses {'ner': 733.9416263103485}
# Losses {'ner': 775.9578865766525}
# Losses {'ner': 828.2640651464462}
# Losses {'ner': 877.222648024559}
# Losses {'ner': 914.7626446485519}
# Losses {'ner': 945.2591818571091}
# Losses {'ner': 981.9784973859787}
# Losses {'ner': 1047.838891863823}
# Losses {'ner': 1119.6160868406296}
# Losses {'ner': 1171.1442540884018}
# Losses {'ner': 1207.6202725172043}
# Losses {'ner': 1230.5415757894516}
# Losses {'ner': 1288.4488800764084}
# Losses {'ner': 1485.6891325712204}
# Losses {'ner': 1531.9893645048141}
# Losses {'ner': 1598.8106735944748}
# Losses {'ner': 1634.714642882347}
# Losses {'ner': 1662.8551174402237}
# Losses {'ner': 1713.4850422143936}
# Losses {'ner': 1758.9982615709305}
# Losses {'ner': 1871.7953807115555}
# Losses {'ner': 1974.6333576440811}
# Losses {'ner': 2025.1020880937576}
# Losses {'ner': 2068.369434952736}
# Losses {'ner': 2111.116830468178}
# Losses {'ner': 2135.6503273248672}
# Losses {'ner': 2169.774983048439}
# Losses {'ner': 2191.1556421518326}
# Losses {'ner': 2234.131602883339}
# Losses {'ner': 2267.364857316017}
# /home/vikram/anaconda3/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "1 Verifly_CPC - SmallBusinessInsurance: SureHits M..." with entities "[(16, 82, 'CLI')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# Losses {'ner': 2303.08339035511}
# Losses {'ner': 2339.5543640851974}
# Losses {'ner': 2385.0630229711533}
# Losses {'ner': 2421.089947581291}
# Losses {'ner': 2471.572889685631}
# Losses {'ner': 2526.786007285118}
# Losses {'ner': 2629.4723876714706}
# Losses {'ner': 2659.3899418115616}
# Losses {'ner': 2706.067607522011}
# Losses {'ner': 2726.164668083191}
# Losses {'ner': 2776.4133501052856}
# Losses {'ner': 2824.0950179100037}
# Losses {'ner': 2911.9591059684753}
# Losses {'ner': 2966.032901287079}
# Losses {'ner': 3041.515498161316}
# Losses {'ner': 3101.9174480438232}
# Losses {'ner': 3196.8952226638794}
# Losses {'ner': 3255.536959886551}
# Losses {'ner': 3311.2325117588043}
# Losses {'ner': 3325.8400418758392}
# Losses {'ner': 3377.094755411148}
# Losses {'ner': 3457.766608476639}
# Losses {'ner': 3514.2773110866547}
# Losses {'ner': 3575.86719250679}
# Losses {'ner': 3617.903891801834}
# Losses {'ner': 3687.084585428238}
# Losses {'ner': 3711.1476607322693}
# Losses {'ner': 3755.176158428192}
# Losses {'ner': 3813.024025440216}
# Losses {'ner': 3839.642642021179}
# Losses {'ner': 3873.0737161636353}
# Losses {'ner': 3919.804570198059}
# Losses {'ner': 3948.8731706142426}
# Losses {'ner': 3976.1009895801544}
# Losses {'ner': 4022.109605550766}
# Losses {'ner': 4046.5494859218597}
# Losses {'ner': 4089.5446026325226}
# Losses {'ner': 4130.424408197403}
# Losses {'ner': 4145.79395711422}
# /home/vikram/anaconda3/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Accounting:Core_Accounting_Service Unbilled Hours-..." with entities "[(35, 49, 'CLI')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
#   3%|▎         | 1/30 [00:02<01:04,  2.21s/it]
# Losses {'ner': 4187.384821295738}
# Losses {'ner': 4230.452259421349}
# Losses {'ner': 4267.179277777672}
# Losses {'ner': 4321.95971763134}
# Losses {'ner': 4359.007039904594}
# Losses {'ner': 4398.061471819878}
# Losses {'ner': 4429.946092963219}
# Losses {'ner': 4459.445915579796}
# Losses {'ner': 4462.679759085178}
# Losses {'ner': 77.05341529846191}
# Losses {'ner': 121.60512065887451}
# Losses {'ner': 138.45220017433167}
# Losses {'ner': 182.4047544002533}
# Losses {'ner': 218.69641017913818}
# Losses {'ner': 275.36989736557007}
# Losses {'ner': 295.5197193622589}
# Losses {'ner': 355.14693570137024}
# Losses {'ner': 401.83169198036194}
# Losses {'ner': 478.5235664844513}
# Losses {'ner': 544.2939827442169}
# Losses {'ner': 566.8995645046234}
# Losses {'ner': 628.6152820587158}
# Losses {'ner': 649.0062036514282}
# Losses {'ner': 675.9119784832001}
# Losses {'ner': 708.1405746936798}
# Losses {'ner': 748.8798825740814}
# Losses {'ner': 796.2994349002838}
# Losses {'ner': 841.9002459049225}
# Losses {'ner': 887.0365545749664}
# Losses {'ner': 933.5847790241241}
# Losses {'ner': 958.4232909679413}
# Losses {'ner': 992.787312746048}
# Losses {'ner': 1029.3633658885956}
# Losses {'ner': 1052.6941769123077}
# Losses {'ner': 1083.240211725235}
# Losses {'ner': 1129.5502588748932}
# Losses {'ner': 1168.0550577640533}
# Losses {'ner': 1205.647125005722}
# Losses {'ner': 1229.0428018569946}
# Losses {'ner': 1277.125126361847}
# Losses {'ner': 1314.5379881858826}
# Losses {'ner': 1353.8082251548767}
# Losses {'ner': 1418.1143679618835}
# Losses {'ner': 1457.1077551841736}
# Losses {'ner': 1477.144518852234}
# Losses {'ner': 1522.3272428512573}
# Losses {'ner': 1573.5474996566772}
# Losses {'ner': 1598.398453950882}
# Losses {'ner': 1623.6542954444885}
# Losses {'ner': 1692.0358815193176}
# Losses {'ner': 1752.6806225776672}
# Losses {'ner': 1810.6682822704315}
# Losses {'ner': 1851.4041764736176}
# Losses {'ner': 1897.587262392044}
# Losses {'ner': 1933.4147818088531}
# Losses {'ner': 1995.9553573131561}
# Losses {'ner': 2038.7555482387543}
# Losses {'ner': 2080.305277109146}
# Losses {'ner': 2108.9367604255676}
# Losses {'ner': 2153.2987456321716}
# Losses {'ner': 2186.1632709503174}
# Losses {'ner': 2241.001787185669}
# Losses {'ner': 2276.8252811431885}
# Losses {'ner': 2323.198570728302}
# Losses {'ner': 2376.775530576706}
# Losses {'ner': 2407.250227689743}
# Losses {'ner': 2445.8428575992584}
# Losses {'ner': 2493.8018605709076}
# Losses {'ner': 2538.8163626194}
# Losses {'ner': 2590.3512332439423}
# Losses {'ner': 2649.16877245903}
# Losses {'ner': 2683.406594514847}
# Losses {'ner': 2721.575001478195}
# Losses {'ner': 2780.4271075725555}
# Losses {'ner': 2822.6711008548737}
# Losses {'ner': 2870.9539697170258}
# Losses {'ner': 2902.5880043506622}
# Losses {'ner': 2957.9142439365387}
# Losses {'ner': 3004.3728783130646}
# Losses {'ner': 3071.1468708515167}
# Losses {'ner': 3103.0584151744843}
# Losses {'ner': 3157.2187745571136}
# Losses {'ner': 3243.434159040451}
# Losses {'ner': 3291.260379076004}
# Losses {'ner': 3322.491866827011}
# Losses {'ner': 3379.019062757492}
# Losses {'ner': 3414.4447429180145}
# Losses {'ner': 3497.455166578293}
# Losses {'ner': 3545.1902520656586}
# Losses {'ner': 3570.78737950325}
# Losses {'ner': 3616.086770057678}
# Losses {'ner': 3640.7148628234863}
#   7%|▋         | 2/30 [00:04<01:01,  2.18s/it]
# Losses {'ner': 3673.4222955703735}
# Losses {'ner': 3712.908148765564}
# Losses {'ner': 3787.8390007019043}
# Losses {'ner': 3833.3921003341675}
# Losses {'ner': 3835.6118890047073}
# Losses {'ner': 38.045775413513184}
# Losses {'ner': 114.58676338195801}
# Losses {'ner': 167.83127665519714}
# Losses {'ner': 198.86746191978455}
# Losses {'ner': 235.03663420677185}
# Losses {'ner': 261.65164613723755}
# Losses {'ner': 285.8048801422119}
# Losses {'ner': 314.08821535110474}
# Losses {'ner': 336.71798300743103}
# Losses {'ner': 372.0652883052826}
# Losses {'ner': 396.9462459087372}
# Losses {'ner': 454.06443905830383}
# Losses {'ner': 502.31716656684875}
# Losses {'ner': 554.9614169597626}
# Losses {'ner': 619.3514301776886}
# Losses {'ner': 644.7422244548798}
# Losses {'ner': 680.4769076108932}
# Losses {'ner': 700.0927475690842}
# Losses {'ner': 727.0580798387527}
# Losses {'ner': 779.5323177576065}
# Losses {'ner': 819.9395691156387}
# Losses {'ner': 884.5601612329483}
# Losses {'ner': 925.174228310585}
# Losses {'ner': 970.7500959634781}
# Losses {'ner': 994.8503724336624}
# Losses {'ner': 1019.3591066598892}
# Losses {'ner': 1065.2841116189957}
# Losses {'ner': 1122.5168491601944}
# Losses {'ner': 1159.6159650087357}
# Losses {'ner': 1193.1001702547073}
# Losses {'ner': 1284.1690102815628}
# Losses {'ner': 1311.7798708677292}
# Losses {'ner': 1364.1851433515549}
# Losses {'ner': 1386.7200845479965}
# Losses {'ner': 1438.5815881490707}
# Losses {'ner': 1483.0116266012192}
# Losses {'ner': 1520.3701952695847}
# Losses {'ner': 1567.2465833425522}
# Losses {'ner': 1613.9254788160324}
# Losses {'ner': 1679.197757601738}
# Losses {'ner': 1709.9523957967758}
# Losses {'ner': 1767.2574108839035}
# Losses {'ner': 1843.51769053936}
# Losses {'ner': 1878.2393893003464}
# Losses {'ner': 1898.6248534917831}
# Losses {'ner': 1922.0720719099045}
# Losses {'ner': 1970.7851861715317}
# Losses {'ner': 2005.8311222791672}
# Losses {'ner': 2040.2451471090317}
# Losses {'ner': 2074.3966006040573}
# Losses {'ner': 2112.7796825170517}
# Losses {'ner': 2161.5103293657303}
# Losses {'ner': 2277.6799355745316}
# Losses {'ner': 2308.792033314705}
# Losses {'ner': 2350.4076730012894}
# Losses {'ner': 2398.802743077278}
# Losses {'ner': 2425.180463910103}
# Losses {'ner': 2460.7261105775833}
# Losses {'ner': 2482.1098560094833}
# Losses {'ner': 2548.310044646263}
# Losses {'ner': 2599.134558558464}
# Losses {'ner': 2641.146551012993}
# Losses {'ner': 2665.4161344766617}
# Losses {'ner': 2693.0612822771072}
# Losses {'ner': 2728.372421860695}
# Losses {'ner': 2756.5447219610214}
# Losses {'ner': 2771.6141387224197}
# Losses {'ner': 2819.8229504823685}
# Losses {'ner': 2904.063424229622}
# Losses {'ner': 2963.5688391923904}
# Losses {'ner': 2987.7639080286026}
# Losses {'ner': 3043.8545850515366}
# Losses {'ner': 3078.9600681066513}
# Losses {'ner': 3125.135085940361}
# Losses {'ner': 3167.776003241539}
# Losses {'ner': 3231.880067706108}
# Losses {'ner': 3268.9606980085373}
# Losses {'ner': 3334.4839791059494}
# Losses {'ner': 3349.118222117424}
# Losses {'ner': 3391.088460803032}
# Losses {'ner': 3422.9885193109512}
# Losses {'ner': 3531.6296001672745}
#  10%|█         | 3/30 [00:06<00:57,  2.12s/it]
# Losses {'ner': 3596.2090064287186}
# Losses {'ner': 3665.172471165657}
# Losses {'ner': 3686.862131714821}
# Losses {'ner': 3732.026575922966}
# Losses {'ner': 3771.8377269506454}
# Losses {'ner': 3777.7292196154594}
# Losses {'ner': 31.8829984664917}
# Losses {'ner': 100.54536533355713}
# Losses {'ner': 139.47314739227295}
# Losses {'ner': 161.82160568237305}
# Losses {'ner': 236.31753158569336}
# Losses {'ner': 280.80714225769043}
# Losses {'ner': 307.33110094070435}
# Losses {'ner': 346.6356439590454}
# Losses {'ner': 388.796217918396}
# Losses {'ner': 435.41332817077637}
# Losses {'ner': 465.96775579452515}
# Losses {'ner': 486.3019161224365}
# Losses {'ner': 511.3589165210724}
# Losses {'ner': 540.5083885192871}
# Losses {'ner': 566.7284569740295}
# Losses {'ner': 595.5425765514374}
# Losses {'ner': 696.0575664043427}
# Losses {'ner': 740.4460790157318}
# Losses {'ner': 766.2649359703064}
# Losses {'ner': 816.2030720710754}
# Losses {'ner': 859.8265309333801}
# Losses {'ner': 897.6026844978333}
# Losses {'ner': 974.2193403244019}
# Losses {'ner': 1009.7488260269165}
# Losses {'ner': 1046.3589797019958}
# Losses {'ner': 1087.0509905815125}
# Losses {'ner': 1118.2508823871613}
# Losses {'ner': 1183.0473940372467}
# Losses {'ner': 1210.8478229045868}
# Losses {'ner': 1289.125996351242}
# Losses {'ner': 1330.3451902866364}
# Losses {'ner': 1369.2290375232697}
# Losses {'ner': 1394.3584191799164}
# Losses {'ner': 1421.9687464237213}
# Losses {'ner': 1438.5082346200943}
# Losses {'ner': 1462.342807650566}
# Losses {'ner': 1495.3133610486984}
# Losses {'ner': 1528.7327069044113}
# Losses {'ner': 1578.4638174772263}
# Losses {'ner': 1630.5516580343246}
# Losses {'ner': 1664.4735435247421}
# Losses {'ner': 1693.4325662851334}
# Losses {'ner': 1736.1314803361893}
# Losses {'ner': 1793.3669520616531}
# Losses {'ner': 1855.6273542642593}
# Losses {'ner': 1896.118564248085}
# Losses {'ner': 1977.6742864847183}
# Losses {'ner': 2014.118757367134}
# Losses {'ner': 2033.9851032495499}
# Losses {'ner': 2066.902530312538}
# Losses {'ner': 2114.846736073494}
# Losses {'ner': 2138.740170121193}
# Losses {'ner': 2175.816797375679}
# Losses {'ner': 2222.1334738731384}
# Losses {'ner': 2244.623532950878}
# Losses {'ner': 2269.417873799801}
# Losses {'ner': 2304.4951724410057}
# Losses {'ner': 2363.7749385237694}
# Losses {'ner': 2414.9673604369164}
# Losses {'ner': 2460.6950330138206}
# Losses {'ner': 2478.2582361102104}
# Losses {'ner': 2518.6214038729668}
# Losses {'ner': 2550.75662869215}
# Losses {'ner': 2652.8531360030174}
# Losses {'ner': 2663.9619594812393}
# Losses {'ner': 2689.478933930397}
# Losses {'ner': 2742.233491063118}
# Losses {'ner': 2790.0829907655716}
# Losses {'ner': 2819.635283589363}
# Losses {'ner': 2899.439289212227}
# Losses {'ner': 3011.7211838960648}
# Losses {'ner': 3037.7436805963516}
# Losses {'ner': 3081.1569567918777}
# Losses {'ner': 3115.5088144540787}
# Losses {'ner': 3143.3386021852493}
# Losses {'ner': 3172.1258066892624}
# Losses {'ner': 3212.1673558950424}
# Losses {'ner': 3240.807764649391}
# Losses {'ner': 3283.0729118585587}
# Losses {'ner': 3332.307700753212}
#  13%|█▎        | 4/30 [00:08<00:54,  2.09s/it]
# Losses {'ner': 3360.517107129097}
# Losses {'ner': 3406.8970490694046}
# Losses {'ner': 3460.611067891121}
# Losses {'ner': 3517.545748114586}
# Losses {'ner': 3566.4169577360153}
# Losses {'ner': 3619.452423930168}
# Losses {'ner': 3673.7846573591232}
# Losses {'ner': 3676.9965127706528}
# Losses {'ner': 60.2909951210022}
# Losses {'ner': 80.49496078491211}
# Losses {'ner': 105.6138846874237}
# Losses {'ner': 137.63207364082336}
# Losses {'ner': 196.30195450782776}
# Losses {'ner': 242.44850420951843}
# Losses {'ner': 288.2049310207367}
# Losses {'ner': 357.11305594444275}
# Losses {'ner': 382.35424304008484}
# Losses {'ner': 448.72151827812195}
# Losses {'ner': 492.99997115135193}
# Losses {'ner': 591.13711810112}
# Losses {'ner': 697.2983558177948}
# Losses {'ner': 721.1297142505646}
# Losses {'ner': 760.8173644542694}
# Losses {'ner': 830.6943719387054}
# Losses {'ner': 872.3503739833832}
# Losses {'ner': 906.5609848499298}
# Losses {'ner': 941.0153720378876}
# Losses {'ner': 981.6093866825104}
# Losses {'ner': 1006.0804328918457}
# Losses {'ner': 1040.0980863571167}
# Losses {'ner': 1069.0288305282593}
# Losses {'ner': 1111.4713835716248}
# Losses {'ner': 1148.3251376152039}
# Losses {'ner': 1176.0263767242432}
# Losses {'ner': 1237.3023858070374}
# Losses {'ner': 1275.0726742744446}
# Losses {'ner': 1298.9613542556763}
# Losses {'ner': 1316.06672000885}
# Losses {'ner': 1360.766923904419}
# Losses {'ner': 1398.1993026733398}
# Losses {'ner': 1420.9540469646454}
# Losses {'ner': 1446.7899253368378}
# Losses {'ner': 1511.2085950374603}
# Losses {'ner': 1558.9416716098785}
# Losses {'ner': 1586.0555684566498}
# Losses {'ner': 1648.9865996837616}
# Losses {'ner': 1676.9444320201874}
# Losses {'ner': 1717.028949022293}
# Losses {'ner': 1773.3353879451752}
# Losses {'ner': 1828.4547927379608}
# Losses {'ner': 1889.1412961483002}
# Losses {'ner': 1953.247116804123}
# Losses {'ner': 1978.4643127918243}
# Losses {'ner': 1997.1552488803864}
# Losses {'ner': 2050.695585489273}
# Losses {'ner': 2091.4962084293365}
# Losses {'ner': 2127.790709733963}
# Losses {'ner': 2164.4664311408997}
# Losses {'ner': 2202.197120666504}
# Losses {'ner': 2226.141916513443}
# Losses {'ner': 2248.1042857170105}
# Losses {'ner': 2294.041321992874}
# Losses {'ner': 2375.298265695572}
# Losses {'ner': 2417.286185026169}
# Losses {'ner': 2477.379330396652}
# Losses {'ner': 2504.6219198703766}
# Losses {'ner': 2539.9836008548737}
# Losses {'ner': 2577.5291628837585}
# Losses {'ner': 2635.0408668518066}
# Losses {'ner': 2686.134473323822}
# Losses {'ner': 2722.162973880768}
# Losses {'ner': 2753.4319281578064}
# Losses {'ner': 2785.9696362018585}
# Losses {'ner': 2805.9010479450226}
# Losses {'ner': 2859.9004004001617}
# Losses {'ner': 2891.978381872177}
# Losses {'ner': 2918.9131145477295}
# Losses {'ner': 2979.58615398407}
# Losses {'ner': 3027.907206058502}
# Losses {'ner': 3048.4766359329224}
# Losses {'ner': 3105.810749053955}
# Losses {'ner': 3144.4838573932648}
# Losses {'ner': 3201.305553674698}
# Losses {'ner': 3247.438257455826}
# Losses {'ner': 3313.825184106827}
# Losses {'ner': 3340.514062166214}
# Losses {'ner': 3381.897889852524}
# Losses {'ner': 3403.4084236621857}
# Losses {'ner': 3449.9629471302032}
# Losses {'ner': 3507.4501402378082}
#  17%|█▋        | 5/30 [00:10<00:51,  2.04s/it]
# Losses {'ner': 3568.40194106102}
# Losses {'ner': 3606.725503206253}
# Losses {'ner': 3641.1242830753326}
# Losses {'ner': 3665.962392807007}
# Losses {'ner': 3691.0301337242126}
# Losses {'ner': 3721.7863753763563}
# Losses {'ner': 41.50513029098511}
# Losses {'ner': 84.14811134338379}
# Losses {'ner': 130.66074991226196}
# Losses {'ner': 155.7610626220703}
# Losses {'ner': 191.3574652671814}
# Losses {'ner': 255.84901475906372}
# Losses {'ner': 309.7556576728821}
# Losses {'ner': 403.60060930252075}
# Losses {'ner': 442.04689502716064}
# Losses {'ner': 489.0456771850586}
# Losses {'ner': 534.9567847251892}
# Losses {'ner': 580.628960609436}
# Losses {'ner': 613.5992133617401}
# Losses {'ner': 625.1118556261063}
# Losses {'ner': 675.1152478456497}
# Losses {'ner': 693.7783282995224}
# Losses {'ner': 727.5618838071823}
# Losses {'ner': 804.777495265007}
# Losses {'ner': 822.8280482590199}
# Losses {'ner': 861.494353801012}
# Losses {'ner': 920.9731927216053}
# Losses {'ner': 969.8083949387074}
# Losses {'ner': 989.1732421219349}
# Losses {'ner': 1066.4457946121693}
# Losses {'ner': 1098.222887068987}
# Losses {'ner': 1149.5776791870594}
# Losses {'ner': 1167.832546979189}
# Losses {'ner': 1208.4704726040363}
# Losses {'ner': 1257.1177332699299}
# Losses {'ner': 1304.0844018757343}
# Losses {'ner': 1354.013119250536}
# Losses {'ner': 1397.6935344040394}
# Losses {'ner': 1424.04733517766}
# Losses {'ner': 1463.9078257381916}
# Losses {'ner': 1488.60122564435}
# Losses {'ner': 1508.1239466965199}
# Losses {'ner': 1558.695570975542}
# Losses {'ner': 1586.4701590836048}
# Losses {'ner': 1623.7096004784107}
# Losses {'ner': 1662.9673803150654}
# Losses {'ner': 1709.3678658306599}
# Losses {'ner': 1761.5336697399616}
# Losses {'ner': 1789.5013397037983}
# Losses {'ner': 1813.8469980061054}
# Losses {'ner': 1836.5366685688496}
# Losses {'ner': 1904.3788292706013}
# Losses {'ner': 1955.4410074055195}
# Losses {'ner': 1983.2699106037617}
# Losses {'ner': 1994.623540788889}
# Losses {'ner': 2029.711100012064}
# Losses {'ner': 2051.66035297513}
# Losses {'ner': 2106.402673512697}
# Losses {'ner': 2152.228617697954}
# Losses {'ner': 2180.256617575884}
# Losses {'ner': 2217.85570910573}
# Losses {'ner': 2247.1845593750477}
# Losses {'ner': 2275.954112559557}
# Losses {'ner': 2324.866905719042}
# Losses {'ner': 2368.733668357134}
# Losses {'ner': 2422.8408937752247}
# Losses {'ner': 2462.331736832857}
# Losses {'ner': 2513.508714944124}
# Losses {'ner': 2567.929146081209}
# Losses {'ner': 2620.1523163616657}
# Losses {'ner': 2682.9195378124714}
# Losses {'ner': 2713.9056625664234}
# Losses {'ner': 2730.058852225542}
# Losses {'ner': 2775.5672712624073}
# Losses {'ner': 2827.7995586693287}
# Losses {'ner': 2867.7578974068165}
# Losses {'ner': 2918.305880576372}
# Losses {'ner': 2946.2283716499805}
# Losses {'ner': 2993.2743058502674}
# Losses {'ner': 3037.1349115669727}
# Losses {'ner': 3117.604841262102}
# Losses {'ner': 3139.9010746777058}
# Losses {'ner': 3178.5446970760822}
# Losses {'ner': 3230.4490998089314}
# Losses {'ner': 3249.072354823351}
#  20%|██        | 6/30 [00:12<00:48,  2.04s/it]
# Losses {'ner': 3314.0571475327015}
# Losses {'ner': 3343.6864552795887}
# Losses {'ner': 3356.3652426302433}
# Losses {'ner': 3394.4926902353764}
# Losses {'ner': 3414.316734343767}
# Losses {'ner': 3454.3590493500233}
# Losses {'ner': 3522.129478007555}
# Losses {'ner': 3619.643285304308}
# Losses {'ner': 3621.4626800492406}
# Losses {'ner': 30.5863618850708}
# Losses {'ner': 70.99048328399658}
# Losses {'ner': 103.34330749511719}
# Losses {'ner': 191.19861030578613}
# Losses {'ner': 223.27784061431885}
# Losses {'ner': 250.31727075576782}
# Losses {'ner': 367.523766040802}
# Losses {'ner': 428.5978207588196}
# Losses {'ner': 456.07649660110474}
# Losses {'ner': 482.00325560569763}
# Losses {'ner': 511.70080065727234}
# Losses {'ner': 542.5627348423004}
# Losses {'ner': 565.0033097267151}
# Losses {'ner': 602.3874182701111}
# Losses {'ner': 655.4824488162994}
# Losses {'ner': 669.0885165333748}
# Losses {'ner': 722.2763102650642}
# Losses {'ner': 740.8224254250526}
# Losses {'ner': 786.1608009934425}
# Losses {'ner': 834.415543615818}
# Losses {'ner': 867.3277965188026}
# Losses {'ner': 903.7641869187355}
# Losses {'ner': 935.6577516198158}
# Losses {'ner': 973.2109690308571}
# Losses {'ner': 1009.0224094986916}
# Losses {'ner': 1046.2186141610146}
# Losses {'ner': 1099.633739054203}
# Losses {'ner': 1125.4936977028847}
# Losses {'ner': 1159.6884289383888}
# Losses {'ner': 1216.6913490891457}
# Losses {'ner': 1267.5406408905983}
# Losses {'ner': 1324.7007866501808}
# Losses {'ner': 1377.8662281632423}
# Losses {'ner': 1449.6871300339699}
# Losses {'ner': 1493.443471968174}
# Losses {'ner': 1538.375506222248}
# Losses {'ner': 1575.2965720295906}
# Losses {'ner': 1617.6766651272774}
# Losses {'ner': 1654.1217840313911}
# Losses {'ner': 1703.8068388104439}
# Losses {'ner': 1736.8068879246712}
# Losses {'ner': 1769.048701107502}
# Losses {'ner': 1810.6659691929817}
# Losses {'ner': 1842.1028979420662}
# Losses {'ner': 1878.2125049233437}
# Losses {'ner': 1918.0283165574074}
# Losses {'ner': 1970.5429444909096}
# Losses {'ner': 1996.5413342118263}
# Losses {'ner': 2035.7416062951088}
# Losses {'ner': 2073.677077829838}
# Losses {'ner': 2129.035605967045}
# Losses {'ner': 2198.9657960534096}
# Losses {'ner': 2229.497057259083}
# Losses {'ner': 2246.9931566119194}
# Losses {'ner': 2269.889850318432}
# Losses {'ner': 2304.7825395464897}
# Losses {'ner': 2366.6826135516167}
# Losses {'ner': 2413.0382258296013}
# Losses {'ner': 2465.4511620402336}
# Losses {'ner': 2512.251983344555}
# Losses {'ner': 2553.565728366375}
# Losses {'ner': 2594.864695727825}
# Losses {'ner': 2626.991765677929}
# Losses {'ner': 2660.988571345806}
# Losses {'ner': 2680.5915645956993}
# Losses {'ner': 2737.302229821682}
# Losses {'ner': 2762.8349449038506}
# Losses {'ner': 2794.83803242445}
# Losses {'ner': 2840.598007619381}
# Losses {'ner': 2889.9562758803368}
# Losses {'ner': 2914.5702993273735}
# Losses {'ner': 2932.4108996987343}
# Losses {'ner': 2980.201115190983}
# Losses {'ner': 3010.039031088352}
# Losses {'ner': 3052.4456439614296}
# Losses {'ner': 3079.916493475437}
# Losses {'ner': 3111.1344609856606}
# Losses {'ner': 3145.6501827836037}
#  23%|██▎       | 7/30 [00:14<00:46,  2.04s/it]
# Losses {'ner': 3204.0238896012306}
# Losses {'ner': 3242.5457568764687}
# Losses {'ner': 3292.620688021183}
# Losses {'ner': 3329.601714193821}
# Losses {'ner': 3359.5168638825417}
# Losses {'ner': 3394.992374956608}
# Losses {'ner': 3465.435996592045}
# Losses {'ner': 3498.831685125828}
# Losses {'ner': 3561.0417447686195}
# Losses {'ner': 3566.5674148201942}
# Losses {'ner': 21.458033561706543}
# Losses {'ner': 59.68788433074951}
# Losses {'ner': 140.42764282226562}
# Losses {'ner': 174.75246143341064}
# Losses {'ner': 260.81217193603516}
# Losses {'ner': 292.74109077453613}
# Losses {'ner': 317.46889543533325}
# Losses {'ner': 378.3962345123291}
# Losses {'ner': 435.49664306640625}
# Losses {'ner': 458.79866766929626}
# Losses {'ner': 488.1246283054352}
# Losses {'ner': 508.1904377937317}
# Losses {'ner': 565.2463283538818}
# Losses {'ner': 627.227686882019}
# Losses {'ner': 668.9464030265808}
# Losses {'ner': 717.5093472003937}
# Losses {'ner': 731.6850965619087}
# Losses {'ner': 759.3328407406807}
# Losses {'ner': 806.2611902356148}
# Losses {'ner': 842.2352731823921}
# Losses {'ner': 895.0243037343025}
# Losses {'ner': 930.2362659573555}
# Losses {'ner': 963.0082395672798}
# Losses {'ner': 985.5750404000282}
# Losses {'ner': 1035.1971607804298}
# Losses {'ner': 1053.4243852496147}
# Losses {'ner': 1099.6283866763115}
# Losses {'ner': 1146.167031466961}
# Losses {'ner': 1193.9400388598442}
# Losses {'ner': 1254.6226121783257}
# Losses {'ner': 1280.0377027392387}
# Losses {'ner': 1312.2215906977654}
# Losses {'ner': 1362.852888762951}
# Losses {'ner': 1400.3709632754326}
# Losses {'ner': 1450.4758149981499}
# Losses {'ner': 1487.1845561861992}
# Losses {'ner': 1515.840745151043}
# Losses {'ner': 1536.9103271365166}
# Losses {'ner': 1572.156608760357}
# Losses {'ner': 1603.1206142306328}
# Losses {'ner': 1629.0085222125053}
# Losses {'ner': 1665.6886898875237}
# Losses {'ner': 1691.1512123942375}
# Losses {'ner': 1744.807581603527}
# Losses {'ner': 1794.8919221758842}
# Losses {'ner': 1856.9406415820122}
# Losses {'ner': 1892.7067505717278}
# Losses {'ner': 1930.2151448130608}
# Losses {'ner': 1950.90408629179}
# Losses {'ner': 1994.2978674769402}
# Losses {'ner': 2020.440781533718}
# Losses {'ner': 2061.140193402767}
# Losses {'ner': 2089.788991391659}
# Losses {'ner': 2110.2128478884697}
# Losses {'ner': 2161.128644168377}
# Losses {'ner': 2211.6842791438103}
# Losses {'ner': 2255.8360676169395}
# Losses {'ner': 2280.4103900790215}
# Losses {'ner': 2300.7208818793297}
# Losses {'ner': 2342.356606900692}
# Losses {'ner': 2426.765097081661}
# Losses {'ner': 2472.7461933493614}
# Losses {'ner': 2527.682627618313}
# Losses {'ner': 2548.3843807578087}
# Losses {'ner': 2568.3104040026665}
# Losses {'ner': 2584.6756252646446}
# Losses {'ner': 2613.2007979750633}
# Losses {'ner': 2671.793057143688}
# Losses {'ner': 2722.4252383112907}
# Losses {'ner': 2779.4111673235893}
# Losses {'ner': 2810.5968028903008}
# Losses {'ner': 2847.536621749401}
# Losses {'ner': 2901.8378416895866}
# Losses {'ner': 2976.221594750881}
# Losses {'ner': 3006.156858384609}
# Losses {'ner': 3047.303873002529}
# Losses {'ner': 3076.0349521040916}
# Losses {'ner': 3122.054756104946}
# Losses {'ner': 3156.325943648815}
# Losses {'ner': 3165.981285095215}
#  27%|██▋       | 8/30 [00:16<00:44,  2.01s/it]
# Losses {'ner': 3263.7706084251404}
# Losses {'ner': 3319.471579551697}
# Losses {'ner': 3410.6406989097595}
# Losses {'ner': 3445.2319283485413}
# Losses {'ner': 3461.7041836977005}
# Losses {'ner': 3515.551314473152}
# Losses {'ner': 3562.7819472551346}
# Losses {'ner': 3567.291514188051}
# Losses {'ner': 47.022525787353516}
# Losses {'ner': 70.63394784927368}
# Losses {'ner': 111.49938106536865}
# Losses {'ner': 163.251784324646}
# Losses {'ner': 195.52587842941284}
# Losses {'ner': 228.48943901062012}
# Losses {'ner': 270.0211305618286}
# Losses {'ner': 320.63705348968506}
# Losses {'ner': 350.25790882110596}
# Losses {'ner': 367.7453052997589}
# Losses {'ner': 407.43885350227356}
# Losses {'ner': 464.73663544654846}
# Losses {'ner': 499.7507493495941}
# Losses {'ner': 525.2593648433685}
# Losses {'ner': 556.9517588615417}
# Losses {'ner': 597.5497159957886}
# Losses {'ner': 628.3790998458862}
# Losses {'ner': 674.6985926628113}
# Losses {'ner': 695.9867103099823}
# Losses {'ner': 716.4692056179047}
# Losses {'ner': 757.3041269779205}
# Losses {'ner': 778.9587235450745}
# Losses {'ner': 796.3009835481644}
# Losses {'ner': 863.2002011537552}
# Losses {'ner': 917.0562258958817}
# Losses {'ner': 950.0340358018875}
# Losses {'ner': 983.5276709794998}
# Losses {'ner': 1005.3700715303421}
# Losses {'ner': 1026.7117048501968}
# Losses {'ner': 1066.4173823595047}
# Losses {'ner': 1138.3976422548294}
# Losses {'ner': 1186.8850704431534}
# Losses {'ner': 1212.7270060777664}
# Losses {'ner': 1268.946984410286}
# Losses {'ner': 1370.0815020799637}
# Losses {'ner': 1391.1034010648727}
# Losses {'ner': 1439.277082324028}
# Losses {'ner': 1475.5457700490952}
# Losses {'ner': 1529.3222717046738}
# Losses {'ner': 1576.4138740301132}
# Losses {'ner': 1622.39481818676}
# Losses {'ner': 1653.7970885038376}
# Losses {'ner': 1680.0103014707565}
# Losses {'ner': 1728.4488281011581}
# Losses {'ner': 1760.4207977056503}
# Losses {'ner': 1802.7572501897812}
# Losses {'ner': 1855.3363698720932}
# Losses {'ner': 1876.443388581276}
# Losses {'ner': 1912.3874126672745}
# Losses {'ner': 1967.5664044618607}
# Losses {'ner': 2020.0658365488052}
# Losses {'ner': 2081.2416857481003}
# Losses {'ner': 2108.902871966362}
# Losses {'ner': 2165.164090037346}
# Losses {'ner': 2191.705929160118}
# Losses {'ner': 2260.9717510938644}
# Losses {'ner': 2316.6639012098312}
# Losses {'ner': 2354.189812064171}
# Losses {'ner': 2403.6913474798203}
# Losses {'ner': 2438.775819659233}
# Losses {'ner': 2463.6774047613144}
# Losses {'ner': 2499.562485575676}
# Losses {'ner': 2523.1922258138657}
# Losses {'ner': 2561.6433919668198}
# Losses {'ner': 2609.3900092840195}
# Losses {'ner': 2652.659078001976}
# Losses {'ner': 2681.8739265203476}
# Losses {'ner': 2749.6427949666977}
# Losses {'ner': 2810.2827199697495}
# Losses {'ner': 2862.3690358400345}
# Losses {'ner': 2887.7434030771255}
# Losses {'ner': 2930.9320393800735}
# Losses {'ner': 2967.8869701623917}
# Losses {'ner': 3032.403828263283}
# Losses {'ner': 3056.7193101644516}
# Losses {'ner': 3072.268678545952}
# Losses {'ner': 3097.8201102018356}
# Losses {'ner': 3140.244740843773}
# Losses {'ner': 3171.119190096855}
# Losses {'ner': 3209.5397814512253}
# Losses {'ner': 3235.248134493828}
# Losses {'ner': 3279.8262547254562}
# Losses {'ner': 3319.0936955213547}
# Losses {'ner': 3345.2872029542923}
# Losses {'ner': 3392.841382622719}
#  30%|███       | 9/30 [00:18<00:42,  2.01s/it]
# Losses {'ner': 3473.754462838173}
# Losses {'ner': 3494.1829406023026}
# Losses {'ner': 3504.244627058506}
# Losses {'ner': 34.27374219894409}
# Losses {'ner': 69.9326229095459}
# Losses {'ner': 99.08102941513062}
# Losses {'ner': 138.77847623825073}
# Losses {'ner': 160.50655364990234}
# Losses {'ner': 208.97334337234497}
# Losses {'ner': 240.06045150756836}
# Losses {'ner': 270.63592648506165}
# Losses {'ner': 293.2889370918274}
# Losses {'ner': 368.0540370941162}
# Losses {'ner': 426.2944598197937}
# Losses {'ner': 524.1811337471008}
# Losses {'ner': 570.4632468223572}
# Losses {'ner': 603.4471445083618}
# Losses {'ner': 635.7690391540527}
# Losses {'ner': 669.4115228652954}
# Losses {'ner': 738.6134924888611}
# Losses {'ner': 757.022777557373}
# Losses {'ner': 802.5352947711945}
# Losses {'ner': 859.0759251117706}
# Losses {'ner': 878.7702894210815}
# Losses {'ner': 914.1952068805695}
# Losses {'ner': 938.098881483078}
# Losses {'ner': 956.3740000724792}
# Losses {'ner': 1009.6931495666504}
# Losses {'ner': 1048.6083641052246}
# Losses {'ner': 1085.7003536224365}
# Losses {'ner': 1116.0202541351318}
# Losses {'ner': 1130.848189651966}
# Losses {'ner': 1181.913171350956}
# Losses {'ner': 1225.8460059762}
# Losses {'ner': 1244.2875817418098}
# Losses {'ner': 1282.012420475483}
# Losses {'ner': 1320.6462839245796}
# Losses {'ner': 1358.6409905552864}
# Losses {'ner': 1392.17683249712}
# Losses {'ner': 1425.2401712536812}
# Losses {'ner': 1474.5344207882881}
# Losses {'ner': 1508.6739171147346}
# Losses {'ner': 1556.2737062573433}
# Losses {'ner': 1603.6866396069527}
# Losses {'ner': 1646.7838171124458}
# Losses {'ner': 1694.581349670887}
# Losses {'ner': 1747.4507811665535}
# Losses {'ner': 1776.2808321118355}
# Losses {'ner': 1823.401107609272}
# Losses {'ner': 1864.5373094677925}
# Losses {'ner': 1898.8933199048042}
# Losses {'ner': 1924.2370248436928}
# Losses {'ner': 2027.734626352787}
# Losses {'ner': 2046.1903074383736}
# Losses {'ner': 2097.2450707554817}
# Losses {'ner': 2166.312231361866}
# Losses {'ner': 2205.050130188465}
# Losses {'ner': 2232.5092354416847}
# Losses {'ner': 2278.3152089715004}
# Losses {'ner': 2339.641795694828}
# Losses {'ner': 2359.4837306141853}
# Losses {'ner': 2393.642128765583}
# Losses {'ner': 2413.13084346056}
# Losses {'ner': 2445.2027738690376}
# Losses {'ner': 2475.766737282276}
# Losses {'ner': 2536.134660065174}
# Losses {'ner': 2575.8917377591133}
# Losses {'ner': 2635.7390592694283}
# Losses {'ner': 2679.343923866749}
# Losses {'ner': 2774.143421471119}
# Losses {'ner': 2810.2151311039925}
# Losses {'ner': 2835.3909237980843}
# Losses {'ner': 2875.2172394394875}
# Losses {'ner': 2898.397513926029}
# Losses {'ner': 2915.2508097290993}
# Losses {'ner': 2952.7740867733955}
# Losses {'ner': 2995.3603132367134}
# Losses {'ner': 3012.126712858677}
# Losses {'ner': 3028.915639936924}
# Losses {'ner': 3065.8301921486855}
# Losses {'ner': 3116.7582007050514}
# Losses {'ner': 3159.91058832407}
# Losses {'ner': 3198.9383566975594}
# Losses {'ner': 3230.077479660511}
# Losses {'ner': 3242.1669169664383}
# Losses {'ner': 3318.5512486696243}
# Losses {'ner': 3377.78131210804}
# Losses {'ner': 3413.854646086693}
# Losses {'ner': 3435.1409405469894}
# Losses {'ner': 3450.674448132515}
#  33%|███▎      | 10/30 [00:20<00:39,  1.97s/it]
# Losses {'ner': 3455.7605713102967}
# Losses {'ner': 62.80032920837402}
# Losses {'ner': 75.17356872558594}
# Losses {'ner': 160.2215073108673}
# Losses {'ner': 198.63148880004883}
# Losses {'ner': 234.19692397117615}
# Losses {'ner': 281.7830741405487}
# Losses {'ner': 312.62509083747864}
# Losses {'ner': 369.74916410446167}
# Losses {'ner': 395.2543535232544}
# Losses {'ner': 421.87411880493164}
# Losses {'ner': 467.2712574005127}
# Losses {'ner': 489.1861091852188}
# Losses {'ner': 535.2851368188858}
# Losses {'ner': 574.3620349168777}
# Losses {'ner': 645.977309346199}
# Losses {'ner': 672.2224563360214}
# Losses {'ner': 695.900293469429}
# Losses {'ner': 724.2129579782486}
# Losses {'ner': 771.2068907022476}
# Losses {'ner': 819.2306624650955}
# Losses {'ner': 855.0573788881302}
# Losses {'ner': 931.3142491579056}
# Losses {'ner': 972.3690110445023}
# Losses {'ner': 999.254634976387}
# Losses {'ner': 1042.319723725319}
# Losses {'ner': 1075.5160156488419}
# Losses {'ner': 1102.8966370821}
# Losses {'ner': 1135.8577276468277}
# Losses {'ner': 1192.9423152208328}
# Losses {'ner': 1226.0227650403976}
# Losses {'ner': 1249.1300729513168}
# Losses {'ner': 1274.995504975319}
# Losses {'ner': 1307.6670585870743}
# Losses {'ner': 1344.9478932619095}
# Losses {'ner': 1380.2898837327957}
# Losses {'ner': 1420.3472658395767}
# Losses {'ner': 1446.0131689310074}
# Losses {'ner': 1502.834044098854}
# Losses {'ner': 1569.2192970514297}
# Losses {'ner': 1600.1308232545853}
# Losses {'ner': 1621.4337671995163}
# Losses {'ner': 1658.4466375112534}
# Losses {'ner': 1686.5179821252823}
# Losses {'ner': 1700.7531751394272}
# Losses {'ner': 1714.7204370498657}
# Losses {'ner': 1764.8712148666382}
# Losses {'ner': 1822.1526250839233}
# Losses {'ner': 1846.0754384994507}
# Losses {'ner': 1874.1173310279846}
# Losses {'ner': 1886.7881072759628}
# Losses {'ner': 1948.6161626577377}
# Losses {'ner': 2003.172677397728}
# Losses {'ner': 2025.741550564766}
# Losses {'ner': 2050.1053179502487}
# Losses {'ner': 2083.3273869752884}
# Losses {'ner': 2111.1323462724686}
# Losses {'ner': 2137.778126835823}
# Losses {'ner': 2159.5184503793716}
# Losses {'ner': 2193.37909924984}
# Losses {'ner': 2215.0529195070267}
# Losses {'ner': 2300.64526951313}
# Losses {'ner': 2328.5100024938583}
# Losses {'ner': 2358.548599123955}
# Losses {'ner': 2418.1380108594894}
# Losses {'ner': 2463.3906868696213}
# Losses {'ner': 2487.4689754247665}
# Losses {'ner': 2546.1438649892807}
# Losses {'ner': 2590.302429318428}
# Losses {'ner': 2611.3640516996384}
# Losses {'ner': 2661.6078642606735}
# Losses {'ner': 2732.5329159498215}
# Losses {'ner': 2791.9446247816086}
# Losses {'ner': 2812.781914114952}
# Losses {'ner': 2868.9661651849747}
# Losses {'ner': 2936.1682316064835}
# Losses {'ner': 2959.7034522295}
# Losses {'ner': 2983.3038407564163}
# Losses {'ner': 3014.8326386213303}
# Losses {'ner': 3062.3362711668015}
#  37%|███▋      | 11/30 [00:22<00:36,  1.95s/it]
# Losses {'ner': 3163.062889933586}
# Losses {'ner': 3200.2297986745834}
# Losses {'ner': 3234.5019429922104}
# Losses {'ner': 3265.874337077141}
# Losses {'ner': 3300.6377695798874}
# Losses {'ner': 3361.222787976265}
# Losses {'ner': 3428.369276046753}
# Losses {'ner': 3454.292578458786}
# Losses {'ner': 3458.0115653276443}
# Losses {'ner': 35.03681993484497}
# Losses {'ner': 75.42933893203735}
# Losses {'ner': 110.8360047340393}
# Losses {'ner': 157.5507788658142}
# Losses {'ner': 181.84518611431122}
# Losses {'ner': 201.45748507976532}
# Losses {'ner': 238.36803996562958}
# Losses {'ner': 265.7338823080063}
# Losses {'ner': 300.4464200735092}
# Losses {'ner': 355.3369730710983}
# Losses {'ner': 409.6919959783554}
# Losses {'ner': 449.31300818920135}
# Losses {'ner': 473.0233072042465}
# Losses {'ner': 512.630986571312}
# Losses {'ner': 540.7937172651291}
# Losses {'ner': 552.682746052742}
# Losses {'ner': 622.1306244134903}
# Losses {'ner': 665.5789490938187}
# Losses {'ner': 747.2432080507278}
# Losses {'ner': 771.0503851175308}
# Losses {'ner': 824.3607000112534}
# Losses {'ner': 864.260884642601}
# Losses {'ner': 896.8891094923019}
# Losses {'ner': 988.2357701063156}
# Losses {'ner': 1016.7890928983688}
# Losses {'ner': 1074.3803740739822}
# Losses {'ner': 1102.897508263588}
# Losses {'ner': 1130.9327238798141}
# Losses {'ner': 1186.4581145048141}
# Losses {'ner': 1217.671477675438}
# Losses {'ner': 1252.3107845783234}
# Losses {'ner': 1266.28604388237}
# Losses {'ner': 1304.7340621948242}
# Losses {'ner': 1340.5922713279724}
# Losses {'ner': 1372.2620906829834}
# Losses {'ner': 1429.1247072219849}
# Losses {'ner': 1461.879280090332}
# Losses {'ner': 1526.051365852356}
# Losses {'ner': 1564.9050061702728}
# Losses {'ner': 1596.4552850723267}
# Losses {'ner': 1644.7956278324127}
# Losses {'ner': 1671.0470974445343}
# Losses {'ner': 1764.1007878780365}
# Losses {'ner': 1786.2636668682098}
# Losses {'ner': 1808.7553534507751}
# Losses {'ner': 1826.1024542450905}
# Losses {'ner': 1860.742707312107}
# Losses {'ner': 1889.7711144089699}
# Losses {'ner': 1963.3098421692848}
# Losses {'ner': 2008.098465025425}
# Losses {'ner': 2056.7475162148476}
# Losses {'ner': 2112.5853260159492}
# Losses {'ner': 2159.050359547138}
# Losses {'ner': 2197.069402515888}
# Losses {'ner': 2239.9910076260567}
# Losses {'ner': 2280.5554717183113}
# Losses {'ner': 2374.4937556385994}
# Losses {'ner': 2398.667793095112}
# Losses {'ner': 2467.2320554852486}
# Losses {'ner': 2507.4628136754036}
# Losses {'ner': 2536.7479761242867}
# Losses {'ner': 2569.7031629681587}
# Losses {'ner': 2629.2032459378242}
# Losses {'ner': 2654.988883316517}
# Losses {'ner': 2670.2912977337837}
# Losses {'ner': 2695.3686149716377}
# Losses {'ner': 2731.93104916811}
# Losses {'ner': 2765.7146349549294}
# Losses {'ner': 2784.131137549877}
# Losses {'ner': 2855.384271323681}
# Losses {'ner': 2892.354114949703}
# Losses {'ner': 2917.9540695548058}
# Losses {'ner': 2964.342396199703}
# Losses {'ner': 2986.0404774546623}
# Losses {'ner': 3018.186505973339}
# Losses {'ner': 3038.1174477934837}
# Losses {'ner': 3088.409304320812}
# Losses {'ner': 3127.9304038882256}
# Losses {'ner': 3143.338165819645}
# Losses {'ner': 3183.278077185154}
# Losses {'ner': 3203.146999657154}
# Losses {'ner': 3242.990029633045}
#  40%|████      | 12/30 [00:23<00:34,  1.93s/it]
# Losses {'ner': 3283.9465611577034}
# Losses {'ner': 3352.341703236103}
# Losses {'ner': 3375.583912909031}
# Losses {'ner': 3407.468859255314}
# Losses {'ner': 3437.7218247056007}
# Losses {'ner': 3443.444353222847}
# Losses {'ner': 31.96689462661743}
# Losses {'ner': 55.752360582351685}
# Losses {'ner': 80.61775135993958}
# Losses {'ner': 108.47761416435242}
# Losses {'ner': 128.1361175775528}
# Losses {'ner': 173.01777565479279}
# Losses {'ner': 215.46358215808868}
# Losses {'ner': 255.61807310581207}
# Losses {'ner': 280.1442281007767}
# Losses {'ner': 323.50832283496857}
# Losses {'ner': 346.96959149837494}
# Losses {'ner': 406.78370702266693}
# Losses {'ner': 425.6014095544815}
# Losses {'ner': 455.2189303636551}
# Losses {'ner': 484.5922762155533}
# Losses {'ner': 520.2719274759293}
# Losses {'ner': 547.3507763147354}
# Losses {'ner': 578.7800914049149}
# Losses {'ner': 656.802658200264}
# Losses {'ner': 687.229208111763}
# Losses {'ner': 736.6164857149124}
# Losses {'ner': 780.1079536676407}
# Losses {'ner': 815.5546232461929}
# Losses {'ner': 838.7224410772324}
# Losses {'ner': 887.2086547613144}
# Losses {'ner': 932.2885264158249}
# Losses {'ner': 1020.6737109422684}
# Losses {'ner': 1046.244532942772}
# Losses {'ner': 1091.9564961194992}
# Losses {'ner': 1125.361211180687}
# Losses {'ner': 1168.5492676496506}
# Losses {'ner': 1180.4428728818893}
# Losses {'ner': 1216.3900030851364}
# Losses {'ner': 1253.8861492872238}
# Losses {'ner': 1299.755691409111}
# Losses {'ner': 1353.7390612363815}
# Losses {'ner': 1389.0460780858994}
# Losses {'ner': 1423.9371901750565}
# Losses {'ner': 1452.0492032766342}
# Losses {'ner': 1482.6465600728989}
# Losses {'ner': 1524.8839710950851}
# Losses {'ner': 1597.851582288742}
# Losses {'ner': 1636.8198413848877}
# Losses {'ner': 1656.2898728847504}
# Losses {'ner': 1700.4545409679413}
# Losses {'ner': 1749.8126828670502}
# Losses {'ner': 1794.4993116855621}
# Losses {'ner': 1825.2152874469757}
# Losses {'ner': 1871.5467927455902}
# Losses {'ner': 1895.5006358623505}
# Losses {'ner': 1915.610989332199}
# Losses {'ner': 1947.6778452396393}
# Losses {'ner': 1985.5959079265594}
# Losses {'ner': 2072.636909723282}
# Losses {'ner': 2109.70801281929}
# Losses {'ner': 2127.3708052635193}
# Losses {'ner': 2197.1435244083405}
# Losses {'ner': 2251.6151599884033}
# Losses {'ner': 2289.764899253845}
# Losses {'ner': 2307.5971549749374}
# Losses {'ner': 2347.0191801786423}
# Losses {'ner': 2389.3120745420456}
# Losses {'ner': 2407.5045791864395}
# Losses {'ner': 2459.0176969766617}
# Losses {'ner': 2509.2308245897293}
# Losses {'ner': 2542.1413868665695}
# Losses {'ner': 2574.0526560544968}
# Losses {'ner': 2617.4108041524887}
# Losses {'ner': 2636.933050274849}
# Losses {'ner': 2651.4628673791885}
# Losses {'ner': 2686.760159134865}
# Losses {'ner': 2722.608168721199}
# Losses {'ner': 2766.414531826973}
# Losses {'ner': 2826.1744590997696}
# Losses {'ner': 2863.448832631111}
# Losses {'ner': 2933.908043026924}
# Losses {'ner': 2963.6077293157578}
# Losses {'ner': 2993.2979403734207}
# Losses {'ner': 3037.581181168556}
# Losses {'ner': 3053.7294696569443}
# Losses {'ner': 3094.0426601171494}
# Losses {'ner': 3137.015854239464}
#  43%|████▎     | 13/30 [00:25<00:33,  1.94s/it]
# Losses {'ner': 3169.6271971464157}
# Losses {'ner': 3253.3925684690475}
# Losses {'ner': 3294.0354984998703}
# Losses {'ner': 3359.7735098600388}
# Losses {'ner': 3383.428566336632}
# Losses {'ner': 3433.4487792253494}
# Losses {'ner': 20.988449573516846}
# Losses {'ner': 47.34898805618286}
# Losses {'ner': 76.36200213432312}
# Losses {'ner': 105.70622897148132}
# Losses {'ner': 148.6663920879364}
# Losses {'ner': 237.83149409294128}
# Losses {'ner': 262.4003186225891}
# Losses {'ner': 316.33031845092773}
# Losses {'ner': 358.6586899757385}
# Losses {'ner': 392.33489990234375}
# Losses {'ner': 455.6787705421448}
# Losses {'ner': 479.3494656085968}
# Losses {'ner': 524.7929217815399}
# Losses {'ner': 553.5341236591339}
# Losses {'ner': 608.0550148487091}
# Losses {'ner': 674.4164803028107}
# Losses {'ner': 689.8514499664307}
# Losses {'ner': 728.13205742836}
# Losses {'ner': 779.5354425907135}
# Losses {'ner': 805.2314252853394}
# Losses {'ner': 821.3908927440643}
# Losses {'ner': 848.8093647956848}
# Losses {'ner': 879.9504976272583}
# Losses {'ner': 949.0188057422638}
# Losses {'ner': 994.4929258823395}
# Losses {'ner': 1016.4494149684906}
# Losses {'ner': 1077.0788323879242}
# Losses {'ner': 1089.922299861908}
# Losses {'ner': 1150.6006774902344}
# Losses {'ner': 1181.449643611908}
# Losses {'ner': 1216.3514604568481}
# Losses {'ner': 1241.6573312282562}
# Losses {'ner': 1269.901787519455}
# Losses {'ner': 1298.9130342006683}
# Losses {'ner': 1319.9568102359772}
# Losses {'ner': 1355.2928493022919}
# Losses {'ner': 1380.228750705719}
# Losses {'ner': 1423.8529925346375}
# Losses {'ner': 1465.786156654358}
# Losses {'ner': 1506.1958100795746}
# Losses {'ner': 1552.104008436203}
# Losses {'ner': 1589.9703333377838}
# Losses {'ner': 1623.1834182739258}
# Losses {'ner': 1643.0972173213959}
# Losses {'ner': 1679.9476664066315}
# Losses {'ner': 1729.2048246860504}
# Losses {'ner': 1748.4837477207184}
# Losses {'ner': 1790.2570402622223}
# Losses {'ner': 1830.782809495926}
# Losses {'ner': 1891.9001486301422}
# Losses {'ner': 1925.105891942978}
# Losses {'ner': 1958.5534842014313}
# Losses {'ner': 1986.1236746311188}
# Losses {'ner': 2047.6682913303375}
# Losses {'ner': 2082.841888666153}
# Losses {'ner': 2108.885306119919}
# Losses {'ner': 2198.4618232250214}
# Losses {'ner': 2255.1086728572845}
# Losses {'ner': 2278.0248856544495}
# Losses {'ner': 2296.054805159569}
# Losses {'ner': 2326.9212247133255}
# Losses {'ner': 2349.8493572473526}
# Losses {'ner': 2379.7325102090836}
# Losses {'ner': 2415.5618768930435}
# Losses {'ner': 2439.459088921547}
# Losses {'ner': 2517.804017663002}
# Losses {'ner': 2547.12781727314}
# Losses {'ner': 2594.1610313653946}
# Losses {'ner': 2663.639970421791}
# Losses {'ner': 2691.965440392494}
# Losses {'ner': 2716.014702439308}
# Losses {'ner': 2748.8742376565933}
# Losses {'ner': 2790.6705275774}
# Losses {'ner': 2874.8432780504227}
# Losses {'ner': 2936.3205600976944}
# Losses {'ner': 2994.6829611063004}
# Losses {'ner': 3036.6230739355087}
# Losses {'ner': 3068.9379221200943}
# Losses {'ner': 3101.7241126298904}
#  47%|████▋     | 14/30 [00:28<00:32,  2.00s/it]
# Losses {'ner': 3150.562068104744}
# Losses {'ner': 3179.4797538518906}
# Losses {'ner': 3201.6833089590073}
# Losses {'ner': 3241.9342535734177}
# Losses {'ner': 3264.521306872368}
# Losses {'ner': 3307.019996523857}
# Losses {'ner': 3364.3199096918106}
# Losses {'ner': 3390.8305283784866}
# Losses {'ner': 3393.0161765404046}
# Losses {'ner': 22.598001956939697}
# Losses {'ner': 45.536977648735046}
# Losses {'ner': 64.27596688270569}
# Losses {'ner': 118.78824353218079}
# Losses {'ner': 160.18266224861145}
# Losses {'ner': 189.07855367660522}
# Losses {'ner': 218.2122664451599}
# Losses {'ner': 241.78362107276917}
# Losses {'ner': 291.3841998577118}
# Losses {'ner': 310.9106984138489}
# Losses {'ner': 341.4759774208069}
# Losses {'ner': 365.14781975746155}
# Losses {'ner': 411.79502415657043}
# Losses {'ner': 447.1104152202606}
# Losses {'ner': 471.33788084983826}
# Losses {'ner': 505.98211550712585}
# Losses {'ner': 563.2400124073029}
# Losses {'ner': 627.9334003925323}
# Losses {'ner': 674.1872885227203}
# Losses {'ner': 703.2557046413422}
# Losses {'ner': 752.9656331539154}
# Losses {'ner': 779.4390046596527}
# Losses {'ner': 856.0155227184296}
# Losses {'ner': 894.9838764667511}
# Losses {'ner': 926.6800482273102}
# Losses {'ner': 963.1640040874481}
# Losses {'ner': 1025.4425246715546}
# Losses {'ner': 1068.5207178592682}
# Losses {'ner': 1105.8447568416595}
# Losses {'ner': 1154.7851073741913}
# Losses {'ner': 1221.0601122379303}
# Losses {'ner': 1282.6725885868073}
# Losses {'ner': 1321.8305313587189}
# Losses {'ner': 1384.3748152256012}
# Losses {'ner': 1397.464477777481}
# Losses {'ner': 1430.102561712265}
# Losses {'ner': 1497.1894676685333}
# Losses {'ner': 1540.7607090473175}
# Losses {'ner': 1591.9482882022858}
# Losses {'ner': 1609.6899030208588}
# Losses {'ner': 1656.3328740596771}
# Losses {'ner': 1691.2634489536285}
# Losses {'ner': 1717.308351278305}
# Losses {'ner': 1737.28784430027}
# Losses {'ner': 1773.7060285806656}
# Losses {'ner': 1797.1754080057144}
# Losses {'ner': 1826.9763671159744}
# Losses {'ner': 1873.996703505516}
# Losses {'ner': 1907.0912145376205}
# Losses {'ner': 1935.4840904474258}
# Losses {'ner': 1986.9406787157059}
# Losses {'ner': 2029.14566385746}
# Losses {'ner': 2060.4299770593643}
# Losses {'ner': 2128.825215935707}
# Losses {'ner': 2188.2018545866013}
# Losses {'ner': 2228.524978995323}
# Losses {'ner': 2266.575609087944}
# Losses {'ner': 2303.702368617058}
# Losses {'ner': 2337.732473254204}
# Losses {'ner': 2379.7105020284653}
# Losses {'ner': 2412.5403856039047}
# Losses {'ner': 2440.3523803949356}
# Losses {'ner': 2469.29428255558}
# Losses {'ner': 2503.6644583940506}
# Losses {'ner': 2584.898819088936}
# Losses {'ner': 2618.951655983925}
# Losses {'ner': 2643.4687002897263}
# Losses {'ner': 2675.607247233391}
# Losses {'ner': 2703.609200358391}
# Losses {'ner': 2748.0618447065353}
# Losses {'ner': 2763.273973584175}
# Losses {'ner': 2783.9346507787704}
# Losses {'ner': 2820.977636218071}
# Losses {'ner': 2896.348781466484}
# Losses {'ner': 2939.4494742155075}
# Losses {'ner': 2973.2634171247482}
# Losses {'ner': 3064.548997759819}
# Losses {'ner': 3091.05537545681}
# Losses {'ner': 3134.723549246788}
# Losses {'ner': 3199.2121990919113}
# Losses {'ner': 3249.4893206357956}
# Losses {'ner': 3268.5357904434204}
# Losses {'ner': 3297.4412698745728}
# Losses {'ner': 3314.810450553894}
# Losses {'ner': 3366.314126968384}
# Losses {'ner': 3405.013074159622}
# Losses {'ner': 3445.545016527176}
#  50%|█████     | 15/30 [00:30<00:30,  2.01s/it]
# Losses {'ner': 3450.125892817974}
# Losses {'ner': 59.99864912033081}
# Losses {'ner': 86.95303773880005}
# Losses {'ner': 124.82992649078369}
# Losses {'ner': 147.30217504501343}
# Losses {'ner': 177.07745695114136}
# Losses {'ner': 206.13266372680664}
# Losses {'ner': 224.93329906463623}
# Losses {'ner': 256.5517249107361}
# Losses {'ner': 304.03088903427124}
# Losses {'ner': 335.36981534957886}
# Losses {'ner': 354.2018132209778}
# Losses {'ner': 388.01704955101013}
# Losses {'ner': 418.7383725643158}
# Losses {'ner': 452.49334478378296}
# Losses {'ner': 507.9005436897278}
# Losses {'ner': 540.749062538147}
# Losses {'ner': 583.1064081192017}
# Losses {'ner': 628.7551789283752}
# Losses {'ner': 663.8646121025085}
# Losses {'ner': 707.5041708946228}
# Losses {'ner': 728.4321596622467}
# Losses {'ner': 776.5898790359497}
# Losses {'ner': 805.0190753936768}
# Losses {'ner': 881.4980888366699}
# Losses {'ner': 917.5342266559601}
# ...
# Losses {'ner': 2729.6052567362785}
# Losses {'ner': 2768.5750054717064}
# Losses {'ner': 2807.808571279049}
# Losses {'ner': 2851.3604297041893}
# Losses {'ner': 2883.244941174984}
# Losses {'ner': 2907.1776060462}
# Losses {'ner': 2925.2793356776237}
# Losses {'ner': 2997.121221244335}
# Losses {'ner': 3030.9917799830437}
# Losses {'ner': 3056.02087944746}
#  83%|████████▎ | 25/30 [00:50<00:10,  2.17s/it]
# Losses {'ner': 3099.661181151867}
# Losses {'ner': 3124.8743545413017}
# Losses {'ner': 3164.0115997195244}
# Losses {'ner': 3235.816602408886}
# Losses {'ner': 3261.1637168973684}
# Losses {'ner': 12.542425155639648}
# Losses {'ner': 53.78811264038086}
# Losses {'ner': 81.29830074310303}
# Losses {'ner': 127.8487696647644}
# Losses {'ner': 156.73563599586487}
# Losses {'ner': 200.16259849071503}
# Losses {'ner': 223.09651148319244}
# Losses {'ner': 250.54201710224152}
# Losses {'ner': 275.5309954881668}
# Losses {'ner': 312.1773806810379}
# Losses {'ner': 343.45622050762177}
# Losses {'ner': 430.31161296367645}
# Losses {'ner': 502.30327451229095}
# Losses {'ner': 515.6100980788469}
# Losses {'ner': 581.4692513495684}
# Losses {'ner': 613.271336749196}
# Losses {'ner': 645.4502288848162}
# Losses {'ner': 671.9813563376665}
# Losses {'ner': 719.4721381217241}
# Losses {'ner': 748.4705483466387}
# Losses {'ner': 770.4912480860949}
# Losses {'ner': 855.9632730036974}
# Losses {'ner': 872.8864383250475}
# Losses {'ner': 923.7956938296556}
# Losses {'ner': 961.2216033488512}
# Losses {'ner': 1060.1505164653063}
# Losses {'ner': 1107.351982548833}
# Losses {'ner': 1152.654822781682}
# Losses {'ner': 1181.303818181157}
# Losses {'ner': 1209.8684970885515}
# Losses {'ner': 1234.7396907359362}
# Losses {'ner': 1290.5734738856554}
# Losses {'ner': 1323.09013171494}
# Losses {'ner': 1379.9649626761675}
# Losses {'ner': 1441.7909028083086}
# Losses {'ner': 1460.6960920840502}
# Losses {'ner': 1497.2904462367296}
# Losses {'ner': 1543.6631230860949}
# Losses {'ner': 1564.47054477036}
# Losses {'ner': 1613.164335206151}
# Losses {'ner': 1672.9472889453173}
# Losses {'ner': 1723.0369987040758}
# Losses {'ner': 1773.793931439519}
# Losses {'ner': 1790.8636040240526}
# Losses {'ner': 1828.5300163775682}
# Losses {'ner': 1864.3211888819933}
# Losses {'ner': 1911.2817782908678}
# Losses {'ner': 1924.5303669124842}
# Losses {'ner': 1939.5313143879175}
# Losses {'ner': 1976.709215655923}
# Losses {'ner': 2020.5147967487574}
# Losses {'ner': 2048.6678710132837}
# Losses {'ner': 2071.0536065250635}
# Losses {'ner': 2097.364893451333}
# Losses {'ner': 2139.451656833291}
# Losses {'ner': 2179.050904288888}
# Losses {'ner': 2217.5477104336023}
# Losses {'ner': 2265.6695852428675}
# Losses {'ner': 2299.6107659488916}
# Losses {'ner': 2326.7407846599817}
# Losses {'ner': 2357.970207467675}
# Losses {'ner': 2372.1555390506983}
# Losses {'ner': 2393.4159679561853}
# Losses {'ner': 2426.232441201806}
# Losses {'ner': 2446.2952375561}
# Losses {'ner': 2477.271758571267}
# Losses {'ner': 2500.8821497112513}
# Losses {'ner': 2528.4333291202784}
# Losses {'ner': 2565.774338260293}
# Losses {'ner': 2595.9875435978174}
# Losses {'ner': 2628.4538078457117}
# Losses {'ner': 2639.9446464926004}
# Losses {'ner': 2664.991980686784}
# Losses {'ner': 2701.243895664811}
# Losses {'ner': 2761.793687954545}
# Losses {'ner': 2823.2132488638163}
# Losses {'ner': 2856.177570477128}
# Losses {'ner': 2906.2892862707376}
# Losses {'ner': 2941.234732285142}
# Losses {'ner': 2971.345320120454}
# Losses
#  87%|████████▋ | 26/30 [00:52<00:08,  2.20s/it]
#  {'ner': 2989.916302099824}
# Losses {'ner': 3017.470877543092}
# Losses {'ner': 3042.4091774374247}
# Losses {'ner': 3067.6864429861307}
# Losses {'ner': 3116.5499798208475}
# Losses {'ner': 3185.3670905977488}
# Losses {'ner': 3223.304928675294}
# Losses {'ner': 3235.554701194167}
# Losses {'ner': 25.325541019439697}
# Losses {'ner': 50.62668442726135}
# Losses {'ner': 78.00642895698547}
# Losses {'ner': 107.59056115150452}
# Losses {'ner': 150.17328584194183}
# Losses {'ner': 190.33767449855804}
# Losses {'ner': 223.06584346294403}
# Losses {'ner': 268.1337283849716}
# Losses {'ner': 290.07387149333954}
# Losses {'ner': 338.5032209157944}
# Losses {'ner': 366.28063809871674}
# Losses {'ner': 395.4033397436142}
# Losses {'ner': 435.2382105588913}
# Losses {'ner': 460.3128880262375}
# Losses {'ner': 486.6644209623337}
# Losses {'ner': 506.5540713071823}
# Losses {'ner': 578.788710474968}
# Losses {'ner': 627.5060161352158}
# Losses {'ner': 695.322275519371}
# Losses {'ner': 732.1759423017502}
# Losses {'ner': 745.251748919487}
# Losses {'ner': 761.2975351810455}
# Losses {'ner': 773.6138229370117}
# Losses {'ner': 810.8569283485413}
# Losses {'ner': 830.7370324134827}
# Losses {'ner': 866.8422846794128}
# Losses {'ner': 894.4850962162018}
# Losses {'ner': 917.7200117111206}
# Losses {'ner': 965.1138710975647}
# Losses {'ner': 986.4235875606537}
# Losses {'ner': 1019.3944382667542}
# Losses {'ner': 1078.125904917717}
# Losses {'ner': 1107.81980407238}
# Losses {'ner': 1129.2642050981522}
# Losses {'ner': 1170.0296331644058}
# Losses {'ner': 1197.2521921396255}
# Losses {'ner': 1227.0623642206192}
# Losses {'ner': 1252.8070603609085}
# Losses {'ner': 1302.1273251771927}
# Losses {'ner': 1337.9621430635452}
# Losses {'ner': 1430.212232708931}
# Losses {'ner': 1482.1628671884537}
# Losses {'ner': 1510.6361459493637}
# Losses {'ner': 1544.4522615671158}
# Losses {'ner': 1613.3526884317398}
# Losses {'ner': 1649.1465479135513}
# Losses {'ner': 1721.7681013345718}
# Losses {'ner': 1753.8904601335526}
# Losses {'ner': 1803.9626415967941}
# Losses {'ner': 1836.7388662099838}
# Losses {'ner': 1864.3255940675735}
# Losses {'ner': 1887.7755135297775}
# Losses {'ner': 1902.8891030550003}
# Losses {'ner': 1917.7162833809853}
# Losses {'ner': 1964.6103175282478}
# Losses {'ner': 1987.872785627842}
# Losses {'ner': 2049.287923872471}
# Losses {'ner': 2110.9265080094337}
# Losses {'ner': 2134.4528101086617}
# Losses {'ner': 2150.9268223643303}
# Losses {'ner': 2199.790488898754}
# Losses {'ner': 2248.178163230419}
# Losses {'ner': 2291.741862952709}
# Losses {'ner': 2324.4086880087852}
# Losses {'ner': 2338.606686294079}
# Losses {'ner': 2414.17397660017}
# Losses {'ner': 2476.2887548804283}
# Losses {'ner': 2496.703956067562}
# Losses {'ner': 2541.6141483187675}
# Losses {'ner': 2554.083118021488}
# Losses {'ner': 2591.3912387490273}
# Losses {'ner': 2621.5836487412453}
# Losses {'ner': 2675.903222322464}
# Losses {'ner': 2720.34157204628}
# Losses {'ner': 2793.423248052597}
# Losses {'ner': 2807.7885813713074}
# Losses {'ner': 2840.778286933899}
# Losses {'ner': 2863.321871995926}
# Losses {'ner': 2917.1015832424164}
# Losses {'ner': 2950.0360939502716}
# Losses {'ner': 2987.452152967453}
# Losses {'ner': 3012.522844314575}
# Losses {'ner': 3029.9510135650635}
# Losses {'ner': 3070.029333591461}
#  90%|█████████ | 27/30 [00:55<00:06,  2.23s/it]
# Losses {'ner': 3144.0585799217224}
# Losses {'ner': 3180.6678700447083}
# Losses {'ner': 3226.8580298423767}
# Losses {'ner': 3235.663334579227}
# Losses {'ner': 29.962072372436523}
# Losses {'ner': 54.88195538520813}
# Losses {'ner': 115.68853068351746}
# Losses {'ner': 159.8488872051239}
# Losses {'ner': 214.42247462272644}
# Losses {'ner': 231.3358974456787}
# Losses {'ner': 256.3485732078552}
# Losses {'ner': 296.48485374450684}
# Losses {'ner': 312.0313811302185}
# Losses {'ner': 346.6190114021301}
# Losses {'ner': 370.60469818115234}
# Losses {'ner': 395.74453043937683}
# Losses {'ner': 445.6007421016693}
# Losses {'ner': 469.3809551000595}
# Losses {'ner': 498.3712352514267}
# Losses {'ner': 532.6081422567368}
# Losses {'ner': 622.7400192022324}
# Losses {'ner': 658.7659219503403}
# Losses {'ner': 691.398709654808}
# Losses {'ner': 706.0216228961945}
# Losses {'ner': 743.7141745090485}
# Losses {'ner': 808.7209894657135}
# Losses {'ner': 851.691654920578}
# Losses {'ner': 892.8465840816498}
# Losses {'ner': 920.8409504890442}
# Losses {'ner': 952.1278228759766}
# Losses {'ner': 1021.710878610611}
# Losses {'ner': 1085.8107693195343}
# Losses {'ner': 1107.858253955841}
# Losses {'ner': 1149.7781443595886}
# Losses {'ner': 1194.9822640419006}
# Losses {'ner': 1227.2859625816345}
# Losses {'ner': 1276.9773421287537}
# Losses {'ner': 1312.209767818451}
# Losses {'ner': 1352.8473365306854}
# Losses {'ner': 1380.9817378520966}
# Losses {'ner': 1411.6477110385895}
# Losses {'ner': 1467.4068686962128}
# Losses {'ner': 1497.2670357227325}
# Losses {'ner': 1522.6131974458694}
# Losses {'ner': 1557.5280779600143}
# Losses {'ner': 1585.8162125349045}
# Losses {'ner': 1608.613917708397}
# Losses {'ner': 1624.8994244337082}
# Losses {'ner': 1653.8852380514145}
# Losses {'ner': 1678.938535809517}
# Losses {'ner': 1724.0379177331924}
# Losses {'ner': 1753.7541533708572}
# Losses {'ner': 1841.4524661302567}
# Losses {'ner': 1867.3328303098679}
# Losses {'ner': 1892.1228054761887}
# Losses {'ner': 1922.328799366951}
# Losses {'ner': 1963.6104508638382}
# Losses {'ner': 1997.4484397172928}
# Losses {'ner': 2030.8524876832962}
# Losses {'ner': 2126.975702404976}
# Losses {'ner': 2157.5956579446793}
# Losses {'ner': 2183.908600449562}
# Losses {'ner': 2229.121718764305}
# Losses {'ner': 2255.2821813821793}
# Losses {'ner': 2291.394439816475}
# Losses {'ner': 2342.8440705537796}
# Losses {'ner': 2369.448586344719}
# Losses {'ner': 2388.714153409004}
# Losses {'ner': 2412.0486756563187}
# Losses {'ner': 2449.2683802843094}
# Losses {'ner': 2461.833011984825}
# Losses {'ner': 2509.6230195760727}
# Losses {'ner': 2548.9757083654404}
# Losses {'ner': 2558.5160043239594}
# Losses {'ner': 2609.9413697719574}
# Losses {'ner': 2655.039808511734}
# Losses {'ner': 2695.3191311359406}
# Losses {'ner': 2727.3472244739532}
# Losses {'ner': 2760.6134264469147}
# Losses {'ner': 2802.523630619049}
# Losses {'ner': 2837.3977103233337}
# Losses {'ner': 2905.4967856407166}
# Losses {'ner': 2936.820932865143}
# Losses {'ner': 3000.0531237125397}
# Losses {'ner': 3031.957605600357}
# Losses {'ner': 3043.2072843313217}
# Losses {'ner': 3070.550412774086}
# Losses {'ner': 3095.6455825567245}
# Losses {'ner': 3139.553438067436}
# Losses {'ner': 3178.278525710106}
# Losses {'ner': 3208.561905503273}
# Losses {'ner': 3234.1653982922435}
#  93%|█████████▎| 28/30 [00:57<00:04,  2.25s/it]
# Losses {'ner': 35.28943920135498}
# Losses {'ner': 71.07767653465271}
# Losses {'ner': 100.95375561714172}
# Losses {'ner': 121.05743551254272}
# Losses {'ner': 155.36130475997925}
# Losses {'ner': 190.82702159881592}
# Losses {'ner': 234.85257387161255}
# Losses {'ner': 266.5381543636322}
# Losses {'ner': 284.5590073466301}
# Losses {'ner': 316.96600979566574}
# Losses {'ner': 358.6381451487541}
# Losses {'ner': 426.7458578944206}
# Losses {'ner': 445.4650943875313}
# Losses {'ner': 506.63967686891556}
# Losses {'ner': 547.6566050648689}
# Losses {'ner': 576.5760787129402}
# Losses {'ner': 628.9701860547066}
# Losses {'ner': 654.8783071637154}
# Losses {'ner': 686.8313749432564}
# Losses {'ner': 719.6971605420113}
# Losses {'ner': 754.0935462117195}
# Losses {'ner': 765.6820469498634}
# Losses {'ner': 794.7797678112984}
# Losses {'ner': 816.1762242913246}
# Losses {'ner': 846.5466161370277}
# Losses {'ner': 873.5193579792976}
# Losses {'ner': 895.7432926297188}
# Losses {'ner': 921.4738066792488}
# Losses {'ner': 957.4160278439522}
# Losses {'ner': 1013.5376165509224}
# Losses {'ner': 1049.32553845644}
# Losses {'ner': 1084.6998680233955}
# Losses {'ner': 1123.3194726109505}
# Losses {'ner': 1140.9442520737648}
# Losses {'ner': 1186.512485563755}
# Losses {'ner': 1243.2253103852272}
# Losses {'ner': 1265.7680113911629}
# Losses {'ner': 1316.696552336216}
# Losses {'ner': 1363.798095047474}
# Losses {'ner': 1385.7282715439796}
# Losses {'ner': 1440.9279943108559}
# Losses {'ner': 1500.188822567463}
# Losses {'ner': 1536.2307751774788}
# Losses {'ner': 1553.1688287258148}
# Losses {'ner': 1607.0690841674805}
# Losses {'ner': 1647.8812851905823}
# Losses {'ner': 1731.59956741333}
# Losses {'ner': 1781.4023027420044}
# Losses {'ner': 1810.654778957367}
# Losses {'ner': 1835.10595536232}
# Losses {'ner': 1861.0015170574188}
# Losses {'ner': 1894.9483892917633}
# Losses {'ner': 1914.0836107730865}
# Losses {'ner': 1979.0886991024017}
# Losses {'ner': 2004.4855988025665}
# Losses {'ner': 2041.0445330142975}
# Losses {'ner': 2095.820060968399}
# Losses {'ner': 2122.9373519420624}
# Losses {'ner': 2159.163531064987}
# Losses {'ner': 2206.4532260894775}
# Losses {'ner': 2253.8489599227905}
# Losses {'ner': 2273.6490247249603}
# Losses {'ner': 2318.1433351039886}
# Losses {'ner': 2341.64812040329}
# Losses {'ner': 2418.5074009895325}
# Losses {'ner': 2440.9417440891266}
# Losses {'ner': 2469.8207993507385}
# Losses {'ner': 2515.2606902122498}
# Losses {'ner': 2559.8411827087402}
# Losses {'ner': 2613.3514783382416}
# Losses {'ner': 2663.4002814292908}
# Losses {'ner': 2685.586458683014}
# Losses {'ner': 2730.2103309631348}
# Losses {'ner': 2750.174076795578}
# Losses {'ner': 2765.4446667432785}
# Losses {'ner': 2818.6573036909103}
# Losses {'ner': 2904.5232552289963}
# Losses {'ner': 2926.452600836754}
# Losses {'ner': 2948.3200644254684}
# Losses {'ner': 2987.710706114769}
# Losses {'ner': 3035.5322746038437}
# Losses {'ner': 3057.6795595884323}
# Losses {'ner': 3099.152513384819}
# Losses {'ner': 3120.390952706337}
# Losses {'ner': 3149.6087456941605}
#  97%|█████████▋| 29/30 [00:59<00:02,  2.26s/it]
# Losses {'ner': 3225.2156196832657}
# Losses {'ner': 3269.5864320993423}
# Losses {'ner': 3275.028653898298}
# Losses {'ner': 22.42706561088562}
# Losses {'ner': 55.790393590927124}
# Losses {'ner': 117.97295212745667}
# Losses {'ner': 145.53264784812927}
# Losses {'ner': 183.33447790145874}
# Losses {'ner': 224.95560312271118}
# Losses {'ner': 253.74021935462952}
# Losses {'ner': 275.9021580219269}
# Losses {'ner': 321.6686751842499}
# Losses {'ner': 345.09603452682495}
# Losses {'ner': 364.56579756736755}
# Losses {'ner': 428.48092770576477}
# Losses {'ner': 445.14167380332947}
# Losses {'ner': 484.9329068660736}
# Losses {'ner': 527.0433223247528}
# Losses {'ner': 553.6901714801788}
# Losses {'ner': 602.5732724666595}
# Losses {'ner': 629.7142231464386}
# Losses {'ner': 645.2917490005493}
# Losses {'ner': 685.1467385292053}
# Losses {'ner': 712.7895369529724}
# Losses {'ner': 734.3780164718628}
# Losses {'ner': 764.9751133918762}
# Losses {'ner': 811.2402873039246}
# Losses {'ner': 847.6402697563171}
# Losses {'ner': 920.5125842094421}
# Losses {'ner': 967.875476360321}
# Losses {'ner': 995.9510378837585}
# Losses {'ner': 1051.2925691604614}
# Losses {'ner': 1112.0691061019897}
# Losses {'ner': 1147.1108508110046}
# Losses {'ner': 1172.796133518219}
# Losses {'ner': 1195.7875986099243}
# Losses {'ner': 1218.8244342803955}
# Losses {'ner': 1254.2463340759277}
# Losses {'ner': 1287.7690534591675}
# Losses {'ner': 1297.2388998270035}
# Losses {'ner': 1342.247771859169}
# Losses {'ner': 1384.0573645830154}
# Losses {'ner': 1416.3277736902237}
# Losses {'ner': 1433.8744316101074}
# Losses {'ner': 1466.2628779411316}
# Losses {'ner': 1524.5797271728516}
# Losses {'ner': 1587.728479385376}
# Losses {'ner': 1619.7178444862366}
# Losses {'ner': 1657.4005930423737}
# Losses {'ner': 1668.8126739263535}
# Losses {'ner': 1727.183377623558}
# Losses {'ner': 1777.681517481804}
# Losses {'ner': 1808.6988328695297}
# Losses {'ner': 1868.6859563589096}
# Losses {'ner': 1910.4688915014267}
# Losses {'ner': 1921.9418547153473}
# Losses {'ner': 1961.7790110111237}
# Losses {'ner': 1987.2826385498047}
# Losses {'ner': 2064.783615589142}
# Losses {'ner': 2094.657828807831}
# Losses {'ner': 2109.5246155261993}
# Losses {'ner': 2134.6769709587097}
# Losses {'ner': 2167.507297039032}
# Losses {'ner': 2198.3552961349487}
# Losses {'ner': 2232.0075120925903}
# Losses {'ner': 2308.9518661499023}
# Losses {'ner': 2341.789450645447}
# Losses {'ner': 2377.774104833603}
# Losses {'ner': 2409.416680574417}
# Losses {'ner': 2432.070813179016}
# Losses {'ner': 2468.316328048706}
# Losses {'ner': 2509.24627161026}
# Losses {'ner': 2528.7386286258698}
# Losses {'ner': 2558.0136835575104}
# Losses {'ner': 2606.9546694755554}
# Losses {'ner': 2645.7981543540955}
# Losses {'ner': 2684.0098462104797}
# Losses {'ner': 2708.083956003189}
# Losses {'ner': 2746.9143846035004}
# Losses {'ner': 2768.8309750556946}
# Losses {'ner': 2806.8898134231567}
# Losses {'ner': 2838.379066467285}
# Losses {'ner': 2889.3625020980835}
# 100%|██████████| 30/30 [01:01<00:00,  2.07s/it]
# Losses {'ner': 2947.815644264221}
# Losses {'ner': 2999.6393508911133}
# Losses {'ner': 3045.1209292411804}
# Losses {'ner': 3070.401665687561}
# Losses {'ner': 3098.9978079795837}
# Losses {'ner': 3135.0347352027893}
# Losses {'ner': 3203.44092464447}
# Losses {'ner': 3210.0688272938132}

# %%
nlp.to_disk("./model_lg")
#save model

# %% [markdown]
# ### Test predictions of unseen data using the trained model

# %%
####load trained ner spacy model

# %%
import pandas as pd
from tqdm import tqdm,trange
import numpy as np
import re
import spacy
import random

# %%
output_dir = './model_lg'
print("Loading from", output_dir)
nlp = spacy.load(output_dir)
# Out:
# Loading from ./model_lg

# %%
### Find out the predicted entities from the eval tab

# %%
df = pd.read_excel('Task.xlsx',sheet_name='eval')
df = df.fillna('')
df['line_item_name'] = df['line_item_name'].astype(str) 
df['line_item_description'] = df['line_item_description'].astype(str) 
df['name_desc'] = np.zeros(len(df))
for i in trange(len(df)):
    df['name_desc'].iloc[i] = df['line_item_name'].iloc[i] + ' ' + df['line_item_description'].iloc[i]
for i in range(len(df)):
    
    df['name_desc'].iloc[i] = " ".join(df['name_desc'].iloc[i].split())
# Out:
#   0%|          | 0/337 [00:00<?, ?it/s]/home/vikram/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 100%|██████████| 337/337 [00:00<00:00, 8898.15it/s]

# %%
df = df[['line_item_name', 'line_item_description', 'canonical_vendor_name',
       'name_desc', 'canonical_line_item_name']]

# %%
# Testing the model
predicted_entities = []
for i in trange(len(df)):
    doc = nlp(df['name_desc'].iloc[i])
    output = [(ent.text, ent.label_) for ent in doc.ents]
    print("Entities:",output)
    try:
        
        predicted_entities.append(output[0][0])  ##check if the model is predicting
    except:
        predicted_entities.append('')  ##append empty string when there are no predictions
# Out:
#   8%|▊         | 28/337 [00:00<00:02, 132.53it/s]
# Entities: [('Management Services May', 'CLI')]
# Entities: [('Acrobat Pro DC', 'CLI')]
# Entities: [('AIEX 96 Pieces', 'CLI')]
# Entities: [('AmazonBasics AAA', 'CLI')]
# Entities: [('AmazonBasics Mesh Trash Can Waste Basket 1', 'CLI')]
# Entities: [('AmazonFresh Mediterranean Extra Virgin Olive Oil, 68 Fl Oz (2L) B01N3LCEDL', 'CLI')]
# Entities: [('Apple 87W USB-C Power Adapter (for MacBook Pro)', 'CLI')]
# Entities: [('Apple iPad 2', 'CLI')]
# Entities: [('Apple iPad with Retina Display', 'CLI')]
# Entities: [('Apple iPad with Retina Display', 'CLI')]
# Entities: [('Assurant B2B 4YR Kitchen Protection Plan with Accidental Damage $50-74', 'CLI')]
# Entities: [('Bose QuietComfort 35 (Series I) Wireless Headphones,', 'CLI')]
# Entities: [('Calculator,Vilcome 12-Digit Solar Battery Office Calculator with Large LCD Display Big Sensitive Button, Dual Power Desktop Calculators (Black) Calculator,Vilcome 12-Digit Solar Battery Office Calculator with Large LCD Display Big Sensitive Button, Dual Power Desktop Calculators (Black)', 'CLI')]
# Entities: [('Dell 130-WATT 3-Prong AC Adapter with 6 FT Power Cord', 'CLI')]
# Entities: [('Logitech K400 Plus Wireless Touch TV Keyboard with Easy Media Control and Built-', 'CLI')]
# Entities: [('Microsoft Natural Ergonomic Keyboard 4000 for Business - Wired', 'CLI')]
# Entities: [('Mouthwash Dispenser Mini (White) -', 'CLI')]
# Entities: [("Mrs. Meyer's Clean Day Hand Lotion, 12 oz (Pack - 1, Basil)", 'CLI')]
# Entities: [('Nespresso Espresso Disposable Paper Cups (100ml) - 50 Pcs', 'CLI')]
# Entities: [('New AC Adapter Fit for Dell XPS 15', 'CLI')]
# Entities: [('Office Chair, Mid Back Leather Desk Chair, Computer Swivel Office Task Chair, Ergonomic Executive Chair with Armrests', 'CLI')]
# Entities: [('OliviaTree 5PCS', 'CLI')]
# Entities: []
# Entities: [('Runpower 87W USB C Power Adapter Charger for MacBook Pro 15 Inch Laptop,with USB-C to USB-C Charge Cable', 'CLI')]
# Entities: [('SquareTrade B2B 3-Year Tablets Accidental Protection Plan ($0-99.99)', 'CLI')]
# Entities: [('SUNLAND Mesh Dish Cloths for Washing Dishes', 'CLI')]
# Entities: [('The Hard Thing About Hard Things:', 'CLI')]
# Entities: [("The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses", 'CLI')]
#  17%|█▋        | 58/337 [00:00<00:01, 139.78it/s]
# Entities: [('Tilting TV Wall Mount Bracket Low Profile for Most 23-55 Inch LED, LCD, OLED, Plasma Flat Screen TVs with VESA 400x400mm Weight up to 115lbs by PERLES', 'CLI')]
# Entities: [('TRENDnet USB-C HD Docking Cube, HDMI, Gigabit Port, USB Docking Station, Supports up to 3840 x 2160 at 30 Hz, TUC-DS1', 'CLI')]
# Entities: [('Whaline 120 Pack Halloween Gift Tags Trick or Treat Craft Label Tags with 130ft Cotton Rope for Halloween Party Favor, Candy Goodie Bag Art', 'CLI')]
# Entities: [('Xbox Wireless Controller - Black', 'CLI')]
# Entities: [('E-mail gift card to: christopher.byrum@thimble.com', 'CLI')]
# Entities: []
# Entities: [('Lenovo 500 Wireless Combo Keyboard & Mouse, Black (GX30H55793)', 'CLI')]
# Entities: []
# Entities: [('1,500-2,000 words', 'CLI')]
# Entities: [('1,500-2,000 words', 'CLI')]
# Entities: [('900-1,500 words', 'CLI')]
# Entities: [('900-1,500 words @', 'CLI')]
# Entities: [('900-1,500 words @', 'CLI')]
# Entities: [('Trial Assignment @ $350 Miscellaneous Professional Liability Insurance, Explained', 'CLI')]
# Entities: [('Overage fee', 'CLI')]
# Entities: []
# Entities: []
# Entities: [('iPad mini Wi-Fi', 'CLI')]
# Entities: [('Mac mini MRTR2LL/A', 'CLI')]
# Entities: [('MBP 13.3', 'CLI')]
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: [('Amazon EC2 Container Registry (ECR)', 'CLI')]
# Entities: []
# Entities: [('Trustwave Managed Rules for AWS WAF - ModSecurity Virtual Patching sold by TrustWave Holdings, Inc.', 'CLI')]
#  27%|██▋       | 92/337 [00:00<00:01, 152.69it/s]
# Entities: []
# Entities: [('Legislative Services in New York State', 'CLI')]
# Entities: []
# Entities: [('Amy Farrer', 'CLI')]
# Entities: [('Andrew Rink', 'CLI')]
# Entities: [('Colin Kendon', 'CLI')]
# Entities: []
# Entities: [('CONS Consulting - Verifly Greybox Security Assessment; 50% at completion; pmt due 3/6/2020', 'CLI')]
# Entities: [('CONS Sales Tax', 'CLI')]
# Entities: [("UK Full Availability Trade Mark Register Search for THIMBLE in class 36 Payment of external searchers' fees", 'CLI')]
# Entities: [('Sidhu, V', 'CLI')]
# Entities: [('Wilner, J', 'CLI')]
# Entities: [('Microsoft Dynamics 365 Business Central Enhancement Plan', 'CLI')]
# Entities: [('48" Cable Tray - TRIMMED TO 36" OVERALL', 'CLI')]
# Entities: [('Brace Leg - Back2Back', 'CLI')]
# Entities: [('Brace Leg - Double', 'CLI')]
# Entities: [('Brace Leg - Single', 'CLI')]
# Entities: [('Cable Floor Box', 'CLI')]
# Entities: [('Jumper 36" (USED FOR 42" TOP), 3-Circ', 'CLI')]
# Entities: [('Single Leg - Center', 'CLI')]
# Entities: [('Universal Screen/Modesty Bracket', 'CLI')]
# Entities: [('Expense Trademark Search Service', 'CLI')]
# Entities: [('DIRECT FILE', 'CLI')]
# Entities: [('DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN', 'CLI')]
# Entities: [('DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN', 'CLI')]
# Entities: []
# Entities: [('DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN', 'CLI')]
# Entities: [('ISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN', 'CLI')]
# Entities: [('DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN', 'CLI')]
# Entities: []
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('NHQU00 FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
#  38%|███▊      | 127/337 [00:00<00:01, 159.93it/s]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: [('FOREIGN FILING', 'CLI')]
# Entities: []
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2020', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2019 MARCH RENEWALS', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2019 FEBRUARY RENEWALS', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2020', 'CLI')]
# Entities: [('SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE', 'CLI')]
# Entities: [('SPECIAL ARRANGEMENT DISCOUNT', 'CLI')]
# Entities: [('SPECIAL ARRANGEMENT DISCOUNT', 'CLI')]
# Entities: [('SPECIAL ARRANGEMENT DISCOUNT 2020', 'CLI')]
# Entities: [('SPECIAL ARRANGEMENT DISCOUNT', 'CLI')]
# Entities: [('STATUTORY REPRESENTATION', 'CLI')]
# Entities: [('STATUTORY REPRESENTATION', 'CLI')]
# Entities: [('Services - Annual Report-Foreign Corp - North Dakota', 'CLI')]
# Entities: []
# Entities: [('Disbursements Obtain', 'CLI')]
# Entities: [('Design Name: tshirtsb Decoration: Screenprinting, 1 color front, 0 color back American Apparel USA-Made Jersey T-shirt', 'CLI')]
#  42%|████▏     | 143/337 [00:00<00:01, 155.07it/s]
# Entities: [('Head of Product Second Retainer Invoice Second Retainer Invoice', 'CLI')]
# Entities: [('Vice President Insurance For securing services of Daversa Partners First Retainer Invoice', 'CLI')]
# Entities: [('VP Business Development For securing services of Daversa Partners First Retainer Invoice', 'CLI')]
# Entities: []
# Entities: [('Total Expenses Billing for professional services in connection with the estimation of a range of value of certain intellectual property assets of Verifly, as of November 30, 2018.', 'CLI')]
# Entities: [('Campaign Management March 2019 Campaign Management', 'CLI')]
# Entities: [('2196269673816849-4106986', 'CLI')]
# Entities: []
# Entities: []
# Entities: [('Service:', 'CLI')]
# Entities: [('Service:', 'CLI')]
# Entities: [('Service:', 'CLI')]
# Entities: [('Service:', 'CLI')]
# Entities: [('Service:', 'CLI')]
# Entities: [('Service:', 'CLI')]
# Entities: [('Estate Day pass', 'CLI')]
# Entities: [('Freshdesk - Estate Monthly plan', 'CLI')]
# Entities: [('Freshchat - Agents', 'CLI')]
# Entities: [('Agents Agents', 'CLI')]
# Entities: [('Freshchat - Agents Freshchat - Agents', 'CLI')]
# Entities: [('Freshchat - Garden Plan - Monthly', 'CLI')]
# Entities: [('Freshchat - Garden Plan - Monthly Freshchat - Garden Plan - Monthly', 'CLI')]
# Entities: [('RENB Directors & Officers', 'CLI')]
# Entities: [('GitHub Actions', 'CLI')]
# Entities: [('GitHub Plan', 'CLI')]
# Entities: [('GitHub Plan', 'CLI')]
# Entities: []
# Entities: []
# Entities: [('Google Ads', 'CLI')]
# Entities: [('Google Ads', 'CLI')]
#  52%|█████▏    | 176/337 [00:01<00:01, 157.10it/s]
# Entities: [('Google Ads', 'CLI')]
# Entities: [('Google Ads', 'CLI')]
# Entities: []
# Entities: []
# Entities: []
# Entities: [('Strategic Finance Team', 'CLI')]
# Entities: [('Strategic Finance Team:J_Lazarus', 'CLI')]
# Entities: [('Strategic Finance Team:L_Smith', 'CLI')]
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: [('Expense Hogan Assessment for JB', 'CLI')]
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: []
# Entities: [('Unlimited InVision Enterprise Users', 'CLI')]
# Entities: [('Promotion 3M9PC46N applied', 'CLI')]
# Entities: [('professional services rendered Schwartz, B', 'CLI')]
# Entities: [('DS Review master lease, telephone conference with client regarding changes, edit and revise sublease, circulate comments', 'CLI')]
# Entities: [('DS Review revised Guaranty, email with client regarding same, circulate redraft', 'CLI')]
# Entities: [('DataGrip Commercial annual subscription', 'CLI')]
# Entities: [('Han Dang Executive Assistant', 'CLI')]
# Entities: [('Fees Initial payment due per our engagement letter dates April 3, 2019 for tax consulting services', 'CLI')]
#  62%|██████▏   | 208/337 [00:01<00:00, 147.59it/s]
# Entities: [('Progress billing for tax consulting services per our engagement letter dated April 3, 2019.', 'CLI')]
# Entities: [('A Comprehensive Guide to Self Employed Business Insurance', 'CLI')]
# Entities: [('Dance Studio and Instructor Insurance', 'CLI')]
# Entities: []
# Entities: [('Short-form landing pages', 'CLI')]
# Entities: []
# Entities: [('Staff photography w/ post production Will produce head shots for all staff members, along with a team photo.', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('DISBURSEMENTS ADVANCED', 'CLI')]
# Entities: [('PROFESSIONAL SERVICES', 'CLI')]
# Entities: [('Professional Services Kwok W Lee', 'CLI')]
# Entities: [('Seth H Ostrow', 'CLI')]
# Entities: [('Advisory Service', 'CLI')]
# Entities: [('Office 365 Advanced Threat Protection (Plan 1) 07/01/2019 - 07/06/2019', 'CLI')]
# Entities: [('Office 365 Business Premium (Month to Month) 03/20/2019 - 04/19/2019', 'CLI')]
# Entities: [('Office 365 E3 06/07/2019 - 07/06/2019', 'CLI')]
# Entities: [('Office 365 E3 06/07/2019 - 06/30/2019', 'CLI')]
# Entities: [('Office 365 E3', 'CLI')]
# Entities: [('Office 365 Extra File Storage (Month to Month) 03/20/2019 - 04/19/2019', 'CLI')]
# Entities: [('SQL Database Single Standard S2 DTUs', 'CLI')]
# Entities: [('SQL Database Single Standard S3 DTUs', 'CLI')]
# Entities: [('SQL Database Single Standard S2 DTUs', 'CLI')]
# Entities: [('SQL Database Single Standard S3 DTUs', 'CLI')]
# Entities: [('Storage Premium Page Blob', 'CLI')]
# Entities: [('Storage Standard Page Blob Disk Write Operations', 'CLI')]
#  72%|███████▏  | 243/337 [00:01<00:00, 156.97it/s]
# Entities: [('Storage Standard Page Blob LRS Data Stored', 'CLI')]
# Entities: [('Storage Standard SSD Managed Disks Disk Operations', 'CLI')]
# Entities: [('Storage Tables Batch Write Operations', 'CLI')]
# Entities: [('Storage Tables Batch Write Operations', 'CLI')]
# Entities: [('Storage Tables', 'CLI')]
# Entities: [('Virtual Machines D/DS Series D2/DS2 US East', 'CLI')]
# Entities: [('Virtual Machines BS Series Windows', 'CLI')]
# Entities: [('Virtual Machines Ev3/', 'CLI')]
# Entities: [('Base charge (4 GB)', 'CLI')]
# Entities: [('Trademark 4862340 renewal 1 class included', 'CLI')]
# Entities: [('ISO Comm.', 'CLI')]
# Entities: [('Care, Custody and Control Pricing Non-Accredited Actuary', 'CLI')]
# Entities: []
# Entities: [('Pingdom Advanced - Monthly 26 Jun 2019 - 26 Jul 2019', 'CLI')]
# Entities: [('Discount code: ANALOGUE', 'CLI')]
# Entities: [('Marketing Services Refer to the contract for a complete breakdown of services', 'CLI')]
# Entities: [('Marketing Services', 'CLI')]
# Entities: [('Marketing Services Content Project', 'CLI')]
# Entities: [('Marketing Services Content Project', 'CLI')]
# Entities: [("Retainer for Current Month's Executive Coaching with Coach Marc Maltz -- for Jay Bregman", 'CLI')]
# Entities: [('Brand Development, Naming (2 of 5)', 'CLI')]
# Entities: [('Brand Development, Naming (3 of 5)', 'CLI')]
# Entities: [('Brand Scope Expansion (2 of 2)', 'CLI')]
# Entities: [('Consulting Launch', 'CLI')]
# Entities: [('Consulting Launch', 'CLI')]
# Entities: []
# Entities: []
# Entities: []
# Entities: [('Domain Renewal - verif.ly - 1 Year/s (2019-01-26 - 2020-01-25) + DNS Management', 'CLI')]
# Entities: []
# Entities: [('Monthly Plus plan Monthly purchase of Slack July 2, 2019 through August 2, 2019', 'CLI')]
# Entities: [('Plus plan Monthly purchase of Slack March 2, 2020 through April 2, 2020', 'CLI')]
# Entities: [('Capacity Annual Purchase - Service through 3/18/2020 *', 'CLI')]
# Entities: [('On Demand - Enterprise - March 2019 RU00113-AWS-US-East Compute Usage', 'CLI')]
#  82%|████████▏ | 275/337 [00:01<00:00, 153.92it/s]
# Entities: [('Staples Carpet Chair Mat, 36" x 48\'\', Crystal Clear (STP-17436) Staples Carpet Chair Mat, 36" x 48\'\', Crystal Clear (STP-17436)', 'CLI')]
# Entities: [('Internet Access Internet Access : New York - Chinatown / LES - Stealth Fiber 1', 'CLI')]
# Entities: []
# Entities: [('m Limited Fixed Cost: Barracuda Sentinel BSENTS001a:', 'CLI'), ('Barracuda Sentinel for Office 365 - subscription license (1 year):', 'CLI')]
# Entities: [('m Limited Fixed Cost: Barracuda Sentinel', 'CLI')]
# Entities: [('jabra:', 'CLI')]
# Entities: [('Billable Expenses Computer Accessories', 'CLI')]
# Entities: [('Engineer Eric Gross', 'CLI')]
# Entities: [('Engineer Michael Kerr', 'CLI')]
# Entities: []
# Entities: [('Billable Services Engineer', 'CLI')]
# Entities: [('Engineer Alex Lora', 'CLI')]
# Entities: [('Engineer Revor Vicencio', 'CLI')]
# Entities: [('Engineer Ajoykumar Rajasekaran', 'CLI')]
# Entities: []
# Entities: [('Leads 43952', 'CLI')]
# Entities: [('Junk hauling', 'CLI')]
# Entities: [('Scotch 11.25" x 8.75', 'CLI')]
# Entities: [('Swedish Fish Soft & Chewâ€¦', 'CLI')]
# Entities: [('TechNY Daily Job', 'CLI')]
# Entities: [('Enterprise Plan - Quarterly', 'CLI')]
# Entities: [('Annual PAYG subscription Plan for 50 panel credits and 50 client credits to be used at anytime before July 10th 2020', 'CLI')]
# Entities: [('Filing Fees - EX Mississippi and West Virginia renewal fees.', 'CLI')]
# Entities: [('Filing Fees - EX OSI-New Mexico', 'CLI')]
# Entities: [('Filing Fees - EX F. Hughes California renewal fee.', 'CLI')]
# Entities: [('Filing Fees - EX F. Hughes New York broker renewal fees.', 'CLI')]
# Entities: [('Filing Fees - EX F. Hughes New York agent renewal fees.', 'CLI')]
# Entities: [('Filing Fees J. Smith individual renewals in the following states with the accompanying state fees: Arizona ($125), Colorado ($103), Georgia ($105), Illinois ($255), Indiana ($95), New Jersey ($155), Pennsylvania ($115), and South Dakota ($85).', 'CLI')]
#  91%|█████████▏| 308/337 [00:02<00:00, 148.07it/s]
# Entities: [('Filing Fees J. Smith license applications in 27 states.', 'CLI')]
# Entities: [('Filing Fees Verifly entity renewal in Washington.', 'CLI')]
# Entities: [('Filing Fees Verifly entity renewal in the following states with the accompanying state fees: Alaska ($80), California ($193), Colorado ($152), District of Columbia ($105), Idaho ($65), Illinois ($155), New Hampshire ($155), New Jersey ($155), Oregon ($155), Pennsylvania ($115), South Dakota ($5), Utah ($90), and West Virginia ($205).', 'CLI')]
# Entities: [('Filing Fees Secretary of State DBA Name Registration in Vermont.', 'CLI')]
# Entities: [('Lexis Fees Monthly Lexis', 'CLI')]
# Entities: [('UPS Fees - EX', 'CLI')]
# Entities: [('UPS Fees Monthly UPS shipment(s).', 'CLI')]
# Entities: [('General Pulled New Mexico affiliation renewal form and list of affiliations.', 'CLI')]
# Entities: [('General CC', 'CLI')]
# Entities: [('KGL Correspondence with New York regarding DP Chnage.', 'CLI')]
# Entities: [('Professional Services KGL', 'CLI')]
# Entities: [('General License', 'CLI')]
# Entities: [('LM Customer referral contract review.', 'CLI')]
# Entities: [('General Designated producer change process', 'CLI')]
# Entities: [('General New Designated producer correspondence regarding existing background questions', 'CLI')]
# Entities: [('General Verifly DP correspondence', 'CLI')]
# Entities: [('LM Subproducer contract structure', 'CLI')]
# Entities: [('Professional Services LM', 'CLI')]
# Entities: [('General LM', 'CLI')]
# Entities: [('General WP', 'CLI')]
# Entities: [('A&A Verifly Minnesota entity renewal.', 'CLI')]
# Entities: [('professional services rendered Book-keeping services for the quarter ended 31st March 2019.', 'CLI')]
# Entities: [('Brian API 0 1.', 'CLI')]
# Entities: [('Gary API 1.', 'CLI')]
# Entities: [('Gary Java 1.', 'CLI')]
# Entities: [('Johnny Java 1.', 'CLI')]
# Entities: [('Johnny API 1.', 'CLI')]
# Entities: [('API 1.', 'CLI')]
# Entities: [('API 1.', 'CLI')]
# Entities: [('API 1.', 'CLI')]
# Entities: [('Winnie API 1.', 'CLI')]
# Entities: [('Isaac Arch 1.', 'CLI')]
# 100%|██████████| 337/337 [00:02<00:00, 152.33it/s]
# Entities: [('Arch 1.', 'CLI')]
# Entities: [('Mike Data 1.', 'CLI')]
# Entities: [('2 Mike Data 1.', 'CLI')]
# Entities: [('Misc Rent (per seat x 17)', 'CLI')]
# Entities: []
# Entities: [('Misc Rent (per seat x 11)', 'CLI')]
# Entities: [('Misc LCD ($425)', 'CLI')]
# Entities: [('misc xiamen ->', 'CLI')]
# Entities: [('Misc nyc', 'CLI')]
# Entities: [('Misc Isaacâ€™s trip for visa interview (round-trip flight and one night hotel)', 'CLI')]
# Entities: [('Misc Rent (per seat x 16)', 'CLI')]
# Entities: [('Misc Rent (per seat x 8)', 'CLI')]
# Entities: [('Misc macbook ($1,500)', 'CLI')]
# Entities: []
# Entities: [('Maggie PM 1.', 'CLI')]
# Entities: [('Tina PM 1.', 'CLI')]
# Entities: []
# Entities: [('Jesse Web 1.', 'CLI')]
# Entities: [('Jesse Web 1.', 'CLI')]
# Entities: [('Web 1.', 'CLI')]
# Entities: [('Sam Web 1.', 'CLI')]
# Entities: [('Sam Web 1.', 'CLI')]
# Entities: [('Sam Web 1.', 'CLI')]
# Entities: [('Conducted a 10-15 minute email survey of up to 6,000 Verifly members Frequencies and cross-tabulation tables: a breakdown that compares all demographic subgroups to the overall response Report', 'CLI')]

# %%
predicted_entities
# Out:
# ['Management Services May',
#  'Acrobat Pro DC',
#  'AIEX 96 Pieces',
#  'AmazonBasics AAA',
#  'AmazonBasics Mesh Trash Can Waste Basket 1',
#  'AmazonFresh Mediterranean Extra Virgin Olive Oil, 68 Fl Oz (2L) B01N3LCEDL',
#  'Apple 87W USB-C Power Adapter (for MacBook Pro)',
#  'Apple iPad 2',
#  'Apple iPad with Retina Display',
#  'Apple iPad with Retina Display',
#  'Assurant B2B 4YR Kitchen Protection Plan with Accidental Damage $50-74',
#  'Bose QuietComfort 35 (Series I) Wireless Headphones,',
#  'Calculator,Vilcome 12-Digit Solar Battery Office Calculator with Large LCD Display Big Sensitive Button, Dual Power Desktop Calculators (Black) Calculator,Vilcome 12-Digit Solar Battery Office Calculator with Large LCD Display Big Sensitive Button, Dual Power Desktop Calculators (Black)',
#  'Dell 130-WATT 3-Prong AC Adapter with 6 FT Power Cord',
#  'Logitech K400 Plus Wireless Touch TV Keyboard with Easy Media Control and Built-',
#  'Microsoft Natural Ergonomic Keyboard 4000 for Business - Wired',
#  'Mouthwash Dispenser Mini (White) -',
#  "Mrs. Meyer's Clean Day Hand Lotion, 12 oz (Pack - 1, Basil)",
#  'Nespresso Espresso Disposable Paper Cups (100ml) - 50 Pcs',
#  'New AC Adapter Fit for Dell XPS 15',
#  'Office Chair, Mid Back Leather Desk Chair, Computer Swivel Office Task Chair, Ergonomic Executive Chair with Armrests',
#  'OliviaTree 5PCS',
#  '',
#  'Runpower 87W USB C Power Adapter Charger for MacBook Pro 15 Inch Laptop,with USB-C to USB-C Charge Cable',
#  'SquareTrade B2B 3-Year Tablets Accidental Protection Plan ($0-99.99)',
#  'SUNLAND Mesh Dish Cloths for Washing Dishes',
#  'The Hard Thing About Hard Things:',
#  "The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",
#  'Tilting TV Wall Mount Bracket Low Profile for Most 23-55 Inch LED, LCD, OLED, Plasma Flat Screen TVs with VESA 400x400mm Weight up to 115lbs by PERLES',
#  'TRENDnet USB-C HD Docking Cube, HDMI, Gigabit Port, USB Docking Station, Supports up to 3840 x 2160 at 30 Hz, TUC-DS1',
#  'Whaline 120 Pack Halloween Gift Tags Trick or Treat Craft Label Tags with 130ft Cotton Rope for Halloween Party Favor, Candy Goodie Bag Art',
#  'Xbox Wireless Controller - Black',
#  'E-mail gift card to: christopher.byrum@thimble.com',
#  '',
#  'Lenovo 500 Wireless Combo Keyboard & Mouse, Black (GX30H55793)',
#  '',
#  '1,500-2,000 words',
#  '1,500-2,000 words',
#  '900-1,500 words',
#  '900-1,500 words @',
#  '900-1,500 words @',
#  'Trial Assignment @ $350 Miscellaneous Professional Liability Insurance, Explained',
#  'Overage fee',
#  '',
#  '',
#  'iPad mini Wi-Fi',
#  'Mac mini MRTR2LL/A',
#  'MBP 13.3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Amazon EC2 Container Registry (ECR)',
#  '',
#  'Trustwave Managed Rules for AWS WAF - ModSecurity Virtual Patching sold by TrustWave Holdings, Inc.',
#  '',
#  'Legislative Services in New York State',
#  '',
#  'Amy Farrer',
#  'Andrew Rink',
#  'Colin Kendon',
#  '',
#  'CONS Consulting - Verifly Greybox Security Assessment; 50% at completion; pmt due 3/6/2020',
#  'CONS Sales Tax',
#  "UK Full Availability Trade Mark Register Search for THIMBLE in class 36 Payment of external searchers' fees",
#  'Sidhu, V',
#  'Wilner, J',
#  'Microsoft Dynamics 365 Business Central Enhancement Plan',
#  '48" Cable Tray - TRIMMED TO 36" OVERALL',
#  'Brace Leg - Back2Back',
#  'Brace Leg - Double',
#  'Brace Leg - Single',
#  'Cable Floor Box',
#  'Jumper 36" (USED FOR 42" TOP), 3-Circ',
#  'Single Leg - Center',
#  'Universal Screen/Modesty Bracket',
#  'Expense Trademark Search Service',
#  'DIRECT FILE',
#  'DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN',
#  'DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN',
#  '',
#  'DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN',
#  'ISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN',
#  'DISBURSEMENT/COST - ANNUAL REPORT/TAX RETURN',
#  '',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'NHQU00 FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  'FOREIGN FILING',
#  '',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2020',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2019 MARCH RENEWALS',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2019 FEBRUARY RENEWALS',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE 2020',
#  'SERVICE FEE - PREPARE & FILE ANNUAL REPORT/TAX RETURN - ANNUAL REPORT MONITORING SERVICE',
#  'SPECIAL ARRANGEMENT DISCOUNT',
#  'SPECIAL ARRANGEMENT DISCOUNT',
#  'SPECIAL ARRANGEMENT DISCOUNT 2020',
#  'SPECIAL ARRANGEMENT DISCOUNT',
#  'STATUTORY REPRESENTATION',
#  'STATUTORY REPRESENTATION',
#  'Services - Annual Report-Foreign Corp - North Dakota',
#  '',
#  'Disbursements Obtain',
#  'Design Name: tshirtsb Decoration: Screenprinting, 1 color front, 0 color back American Apparel USA-Made Jersey T-shirt',
#  'Head of Product Second Retainer Invoice Second Retainer Invoice',
#  'Vice President Insurance For securing services of Daversa Partners First Retainer Invoice',
#  'VP Business Development For securing services of Daversa Partners First Retainer Invoice',
#  '',
#  'Total Expenses Billing for professional services in connection with the estimation of a range of value of certain intellectual property assets of Verifly, as of November 30, 2018.',
#  'Campaign Management March 2019 Campaign Management',
#  '2196269673816849-4106986',
#  '',
#  '',
#  'Service:',
#  'Service:',
#  'Service:',
#  'Service:',
#  'Service:',
#  'Service:',
#  'Estate Day pass',
#  'Freshdesk - Estate Monthly plan',
#  'Freshchat - Agents',
#  'Agents Agents',
#  'Freshchat - Agents Freshchat - Agents',
#  'Freshchat - Garden Plan - Monthly',
#  'Freshchat - Garden Plan - Monthly Freshchat - Garden Plan - Monthly',
#  'RENB Directors & Officers',
#  'GitHub Actions',
#  'GitHub Plan',
#  'GitHub Plan',
#  '',
#  '',
#  'Google Ads',
#  'Google Ads',
#  'Google Ads',
#  'Google Ads',
#  '',
#  '',
#  '',
#  'Strategic Finance Team',
#  'Strategic Finance Team:J_Lazarus',
#  'Strategic Finance Team:L_Smith',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Expense Hogan Assessment for JB',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Unlimited InVision Enterprise Users',
#  'Promotion 3M9PC46N applied',
#  'professional services rendered Schwartz, B',
#  'DS Review master lease, telephone conference with client regarding changes, edit and revise sublease, circulate comments',
#  'DS Review revised Guaranty, email with client regarding same, circulate redraft',
#  'DataGrip Commercial annual subscription',
#  'Han Dang Executive Assistant',
#  'Fees Initial payment due per our engagement letter dates April 3, 2019 for tax consulting services',
#  'Progress billing for tax consulting services per our engagement letter dated April 3, 2019.',
#  'A Comprehensive Guide to Self Employed Business Insurance',
#  'Dance Studio and Instructor Insurance',
#  '',
#  'Short-form landing pages',
#  '',
#  'Staff photography w/ post production Will produce head shots for all staff members, along with a team photo.',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'DISBURSEMENTS ADVANCED',
#  'PROFESSIONAL SERVICES',
#  'Professional Services Kwok W Lee',
#  'Seth H Ostrow',
#  'Advisory Service',
#  'Office 365 Advanced Threat Protection (Plan 1) 07/01/2019 - 07/06/2019',
#  'Office 365 Business Premium (Month to Month) 03/20/2019 - 04/19/2019',
#  'Office 365 E3 06/07/2019 - 07/06/2019',
#  'Office 365 E3 06/07/2019 - 06/30/2019',
#  'Office 365 E3',
#  'Office 365 Extra File Storage (Month to Month) 03/20/2019 - 04/19/2019',
#  'SQL Database Single Standard S2 DTUs',
#  'SQL Database Single Standard S3 DTUs',
#  'SQL Database Single Standard S2 DTUs',
#  'SQL Database Single Standard S3 DTUs',
#  'Storage Premium Page Blob',
#  'Storage Standard Page Blob Disk Write Operations',
#  'Storage Standard Page Blob LRS Data Stored',
#  'Storage Standard SSD Managed Disks Disk Operations',
#  'Storage Tables Batch Write Operations',
#  'Storage Tables Batch Write Operations',
#  'Storage Tables',
#  'Virtual Machines D/DS Series D2/DS2 US East',
#  'Virtual Machines BS Series Windows',
#  'Virtual Machines Ev3/',
#  'Base charge (4 GB)',
#  'Trademark 4862340 renewal 1 class included',
#  'ISO Comm.',
#  'Care, Custody and Control Pricing Non-Accredited Actuary',
#  '',
#  'Pingdom Advanced - Monthly 26 Jun 2019 - 26 Jul 2019',
#  'Discount code: ANALOGUE',
#  'Marketing Services Refer to the contract for a complete breakdown of services',
#  'Marketing Services',
#  'Marketing Services Content Project',
#  'Marketing Services Content Project',
#  "Retainer for Current Month's Executive Coaching with Coach Marc Maltz -- for Jay Bregman",
#  'Brand Development, Naming (2 of 5)',
#  'Brand Development, Naming (3 of 5)',
#  'Brand Scope Expansion (2 of 2)',
#  'Consulting Launch',
#  'Consulting Launch',
#  '',
#  '',
#  '',
#  'Domain Renewal - verif.ly - 1 Year/s (2019-01-26 - 2020-01-25) + DNS Management',
#  '',
#  'Monthly Plus plan Monthly purchase of Slack July 2, 2019 through August 2, 2019',
#  'Plus plan Monthly purchase of Slack March 2, 2020 through April 2, 2020',
#  'Capacity Annual Purchase - Service through 3/18/2020 *',
#  'On Demand - Enterprise - March 2019 RU00113-AWS-US-East Compute Usage',
#  'Staples Carpet Chair Mat, 36" x 48\'\', Crystal Clear (STP-17436) Staples Carpet Chair Mat, 36" x 48\'\', Crystal Clear (STP-17436)',
#  'Internet Access Internet Access : New York - Chinatown / LES - Stealth Fiber 1',
#  '',
#  'm Limited Fixed Cost: Barracuda Sentinel BSENTS001a:',
#  'm Limited Fixed Cost: Barracuda Sentinel',
#  'jabra:',
#  'Billable Expenses Computer Accessories',
#  'Engineer Eric Gross',
#  'Engineer Michael Kerr',
#  '',
#  'Billable Services Engineer',
#  'Engineer Alex Lora',
#  'Engineer Revor Vicencio',
#  'Engineer Ajoykumar Rajasekaran',
#  '',
#  'Leads 43952',
#  'Junk hauling',
#  'Scotch 11.25" x 8.75',
#  'Swedish Fish Soft & Chewâ€¦',
#  'TechNY Daily Job',
#  'Enterprise Plan - Quarterly',
#  'Annual PAYG subscription Plan for 50 panel credits and 50 client credits to be used at anytime before July 10th 2020',
#  'Filing Fees - EX Mississippi and West Virginia renewal fees.',
#  'Filing Fees - EX OSI-New Mexico',
#  'Filing Fees - EX F. Hughes California renewal fee.',
#  'Filing Fees - EX F. Hughes New York broker renewal fees.',
#  'Filing Fees - EX F. Hughes New York agent renewal fees.',
#  'Filing Fees J. Smith individual renewals in the following states with the accompanying state fees: Arizona ($125), Colorado ($103), Georgia ($105), Illinois ($255), Indiana ($95), New Jersey ($155), Pennsylvania ($115), and South Dakota ($85).',
#  'Filing Fees J. Smith license applications in 27 states.',
#  'Filing Fees Verifly entity renewal in Washington.',
#  'Filing Fees Verifly entity renewal in the following states with the accompanying state fees: Alaska ($80), California ($193), Colorado ($152), District of Columbia ($105), Idaho ($65), Illinois ($155), New Hampshire ($155), New Jersey ($155), Oregon ($155), Pennsylvania ($115), South Dakota ($5), Utah ($90), and West Virginia ($205).',
#  'Filing Fees Secretary of State DBA Name Registration in Vermont.',
#  'Lexis Fees Monthly Lexis',
#  'UPS Fees - EX',
#  'UPS Fees Monthly UPS shipment(s).',
#  'General Pulled New Mexico affiliation renewal form and list of affiliations.',
#  'General CC',
#  'KGL Correspondence with New York regarding DP Chnage.',
#  'Professional Services KGL',
#  'General License',
#  'LM Customer referral contract review.',
#  'General Designated producer change process',
#  'General New Designated producer correspondence regarding existing background questions',
#  'General Verifly DP correspondence',
#  'LM Subproducer contract structure',
#  'Professional Services LM',
#  'General LM',
#  'General WP',
#  'A&A Verifly Minnesota entity renewal.',
#  'professional services rendered Book-keeping services for the quarter ended 31st March 2019.',
#  'Brian API 0 1.',
#  'Gary API 1.',
#  'Gary Java 1.',
#  'Johnny Java 1.',
#  'Johnny API 1.',
#  'API 1.',
#  'API 1.',
#  'API 1.',
#  'Winnie API 1.',
#  'Isaac Arch 1.',
#  'Arch 1.',
#  'Mike Data 1.',
#  '2 Mike Data 1.',
#  'Misc Rent (per seat x 17)',
#  '',
#  'Misc Rent (per seat x 11)',
#  'Misc LCD ($425)',
#  'misc xiamen ->',
#  'Misc nyc',
#  'Misc Isaacâ€™s trip for visa interview (round-trip flight and one night hotel)',
#  'Misc Rent (per seat x 16)',
#  'Misc Rent (per seat x 8)',
#  'Misc macbook ($1,500)',
#  '',
#  'Maggie PM 1.',
#  'Tina PM 1.',
#  '',
#  'Jesse Web 1.',
#  'Jesse Web 1.',
#  'Web 1.',
#  'Sam Web 1.',
#  'Sam Web 1.',
#  'Sam Web 1.',
#  'Conducted a 10-15 minute email survey of up to 6,000 Verifly members Frequencies and cross-tabulation tables: a breakdown that compares all demographic subgroups to the overall response Report']

# %%
df['predicted_canonical_line_item_name'] = predicted_entities

# %%
df = df.drop(['canonical_line_item_name'],axis=1)

# %%
df
# Out:
#                                         line_item_name  \
# 0                                  Management Services
# 1                                       Acrobat Pro DC
# 2    AIEX 96 Pieces Adhesive Poster Tacky Putty Sti...
# 3    AmazonBasics AAA 1.5 Volt Performance Alkaline...
# 4             AmazonBasics Mesh Trash Can Waste Basket
# ..                                                 ...
# 332                                                Web
# 333                                            Sam Web
# 334                                            Sam Web
# 335                                            Sam Web
# 336  Conducted a 10-15 minute email survey of up to...
#
#                                  line_item_description canonical_vendor_name  \
# 0                                    May 2019 Services    10 Minute Ventures
# 1                                                                      Adobe
# 2                                                            Amazon Business
# 3                                                            Amazon Business
# 4                                                    1       Amazon Business
# ..                                                 ...                   ...
# 332  1. Thimble Monthly Webapp 2. Customer Referral...    Xiamen ZhiZhi Tech
# 333  1. Web app 2.0 mobile version  2. Purchase wid...    Xiamen ZhiZhi Tech
# 334    1. Segment Integration  2. Iterable Integration    Xiamen ZhiZhi Tech
# 335  1. Broker Purchase Project 2. New Insurance Pr...    Xiamen ZhiZhi Tech
# 336                                                          Zogby Analytics
#
#                                              name_desc  \
# 0                Management Services May 2019 Services
# 1                                       Acrobat Pro DC
# 2    AIEX 96 Pieces Adhesive Poster Tacky Putty Sti...
# 3    AmazonBasics AAA 1.5 Volt Performance Alkaline...
# 4           AmazonBasics Mesh Trash Can Waste Basket 1
# ..                                                 ...
# 332  Web 1. Thimble Monthly Webapp 2. Customer Refe...
# 333  Sam Web 1. Web app 2.0 mobile version 2. Purch...
# 334  Sam Web 1. Segment Integration 2. Iterable Int...
# 335  Sam Web 1. Broker Purchase Project 2. New Insu...
# 336  Conducted a 10-15 minute email survey of up to...
#
#                     predicted_canonical_line_item_name
# 0                              Management Services May
# 1                                       Acrobat Pro DC
# 2                                       AIEX 96 Pieces
# 3                                     AmazonBasics AAA
# 4           AmazonBasics Mesh Trash Can Waste Basket 1
# ..                                                 ...
# 332                                             Web 1.
# 333                                         Sam Web 1.
# 334                                         Sam Web 1.
# 335                                         Sam Web 1.
# 336  Conducted a 10-15 minute email survey of up to...
#
# [337 rows x 5 columns]

# %%
df.to_csv('eval_predictions_lg.csv',index=False)

# %% [markdown]
# ### Observation and Results:
#
# - We trained and fine tuned the model using a few hundred datapoints,so the results are far from perfect. So the model has not generalized perfectly but it does a decent job. This approach gives us a good starting point to identify and map custom entities.
# - The predicted entites / results obtained from 3 models are present in 3 different csv files inside folder output_eval.
# - Result maybe further improved by using more data,providing annotations in a better way or changing the model's parameters while training.
